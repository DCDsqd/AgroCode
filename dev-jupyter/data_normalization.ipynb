# %%
import pandas as pd
import sqlite3
from autocorrect import Speller
import translators as ts
import roman
import re
import json
from datetime import datetime
from dateutil.relativedelta import relativedelta
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pymorphy2

# %%
# Подключение к базе данных
db_path = '../db/data.db'
conn = sqlite3.connect(db_path)

# Загрузка конфига
with open('../cfg/config.json', 'r', encoding="utf-8") as file:
    cfg = json.load(file)

# %%
# Загрузка данных из каждой таблицы в отдельный DataFrame
person_df = pd.read_sql("SELECT * FROM person", conn)
education_df = pd.read_sql("SELECT * FROM education", conn)
jobs_df = pd.read_sql("SELECT * FROM jobs", conn)

# %%
def to_lower(text: str) -> str:
    return text.lower()

def cut(text: str) -> str:
    symbols_for_cut = [",", "(", ";", ":"]
    for symbol in symbols_for_cut:
        idx = text.find(symbol)
        if idx != -1:
            text = text[:idx]
    return text

jobs_df['job_name_norm'] = jobs_df['job_name'].apply(to_lower)
jobs_df['job_name_norm'] = jobs_df['job_name_norm'].apply(cut)

jobs_df['job_name_norm'] = jobs_df['job_name_norm'].str.replace(".", " ")
jobs_df['job_name_norm'] = jobs_df['job_name_norm'].str.replace("ё", "е")

# Использование регулярного выражения для замены двух или более пробелов на один пробел
def replace_multiple_spaces(input_string):
    return re.sub(' +', ' ', input_string)

jobs_df['job_name_norm'] = jobs_df['job_name_norm'].apply(replace_multiple_spaces)

# Использование регулярного выражения для замены любого количества табов на один пробел
def replace_tabs_with_space(input_string):
    return re.sub('\t+', ' ', input_string)

jobs_df['job_name_norm'] = jobs_df['job_name_norm'].apply(replace_tabs_with_space)


# Словарь для расшифровки сокращений
abbreviation_dict = cfg["abbreviation_dict"]

# Функция для расшифровки сокращений в названиях должностей
def expand_abbreviations(job_name, abbr_dict=abbreviation_dict):
    job_name = " " + job_name + " "
    for abbr, full_form in abbr_dict.items():
        job_name = job_name.replace(" " + abbr + " ", " " + full_form + " ")
    return job_name.strip()

jobs_df['job_name_norm'] = jobs_df['job_name_norm'].apply(expand_abbreviations)

jobs_df['job_name_norm'] = jobs_df['job_name_norm'].str.replace(r"\s*-\s*", "-", regex=True)
jobs_df['job_name_norm'] = jobs_df['job_name_norm'].str.replace(r"\s*/\s*", " / ", regex=True)

# функция, которая преобразует римские цифры в арабские в строке
def roman_to_arabic(input_string):
    def replace_roman_numerals(match):
        try:
            return str(roman.fromRoman(match.group().upper()))
        except roman.InvalidRomanNumeralError:
            return match.group()

    # Регулярное выражение для поиска римских цифр
    roman_numeral_pattern = r'\bM{0,4}(CM|CD|D?C{0,3})(XC|XL|L?X{0,3})(IX|IV|V?I{0,3})\b'

    # Заменяем римские цифры на арабские
    res = re.sub(roman_numeral_pattern, replace_roman_numerals, input_string, flags=re.IGNORECASE)
    if res != input_string:
        print(f"roman_to_arabic() {input_string} -> {res}")
    return res

jobs_df['job_name_norm'] = jobs_df['job_name_norm'].apply(roman_to_arabic)

def drop_everything_after_first_digit(input_string: str) -> str:
    for index, char in enumerate(input_string):
        if char.isdigit():
            return input_string[:index]
    return input_string

jobs_df['job_name_norm'] = jobs_df['job_name_norm'].apply(drop_everything_after_first_digit)

def remove_reducant_spaces(text: str) -> str:
    return text.strip()

jobs_df['job_name_norm'] = jobs_df['job_name_norm'].apply(remove_reducant_spaces)

# Работает только с подключеним к сети
def translate_all(input_string: str) -> str:
    def contains_english_letters(text):
        return bool(re.search(r'[a-zA-Z]', text))

    if contains_english_letters(input_string):
        translate = ts.translate_text(input_string, translator='bing', from_language="en", to_language="ru").lower()
        return translate
    else:
        return input_string

if cfg['apply_eng_to_ru_translation']:
    jobs_df['job_name_norm'] = jobs_df['job_name_norm'].apply(translate_all)

pd.set_option('display.max_rows', 10)
jobs_df
# Out:
# C:\Users\Yurik\AppData\Local\Temp\ipykernel_13244\744234803.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   jobs_df['job_name_norm'] = jobs_df['job_name_norm'].str.replace(".", " ")
# roman_to_arabic() инженер iii категория -> инженер 3 категория
#         id                                           job_name  person_id  \
# 0        1                                  Ветеринарный врач          1
# 1        2                                  Ветеринарный врач          1
# 2        3                                Тракторист-машинист          2
# 3        4                                Тракторист-машинист          2
# 4        5                                            Агроном          3
# ...    ...                                                ...        ...
# 4330  4331  ст инженер, гл. инженер,зам.директора по произ...       1000
# 4331  4332                                          Зоотехник       1001
# 4332  4333                                          Зоотехник       1001
# 4333  4334                   Помощник зоотехника по кормлению       1001
# 4334  4335                                Помощник зоотехника       1001
#
#                                                    desc          start  \
# 0     Планирование и проведение ветеринарных лечебно...    Август 2018
# 1                                     Ветеринарный врач    Август 2018
# 2     -работа на тракторе Джон-Дир 8020\n-ТО и ремон...    Август 2014
# 3     -оператор з/у комбайна Джон Дир\n-ремонт и ТО:...      Июль 2013
# 4                                                     -  Сентябрь 2018
# ...                                                 ...            ...
# 4330  Организация работы. эксплуатация , техническое...    Август 1976
# 4331  Контроль поедаемости кормов животными.\nКоррек...    Август 2020
# 4332  Контроль кормления коров.\nЗаготовка сена.\nПр...   Декабрь 2019
# 4333  Контроль поедаемости кормов животными.\nКоррек...  Сентябрь 2019
# 4334  Практика. Помощь в сортировке дойного стада по...      Июнь 2019
#
#                 end                     job_name_norm
# 0              None                 ветеринарный врач
# 1       Ноябрь 2019                 ветеринарный врач
# 2      Октябрь 2014               тракторист-машинист
# 3     Сентябрь 2013               тракторист-машинист
# 4              None                           агроном
# ...             ...                               ...
# 4330           None                   старший инженер
# 4331           None                         зоотехник
# 4332    Август 2020                         зоотехник
# 4333    Ноябрь 2019  помощник зоотехника по кормлению
# 4334    Август 2019               помощник зоотехника
#
# [4335 rows x 7 columns]

# %%
is_spell_check_activated = cfg["activate_spell_check"]
if is_spell_check_activated:
    spell = Speller("ru")
    # spell.nlp_data.update()
    
    def correct(text: str) -> str:
        res = str(spell(text))
        if res != text:
            print("autocorrect corrected " + text + " -> " + res)
        return res
    
    jobs_df['job_name_norm'] = jobs_df['job_name_norm'].apply(correct)
# Out:
# autocorrect corrected оператов прессов-грануляторов -> оператор прессов-грануляторов
# autocorrect corrected машинист вшм -> машинист вам
# autocorrect corrected механик по ремонту атомобилей -> механик по ремонту автомобилей
# autocorrect corrected дефектоскопист -> дефектоскопии
# autocorrect corrected дефектоскопист -> дефектоскопии
# autocorrect corrected глава новониколевского мо -> глава новониколаевского мо
# autocorrect corrected руководитель магазина продажа с\х запчастей г искитим -> руководитель магазина продажа с\х запчастей г искити
# autocorrect corrected эксковаторщик -> экскаваторщик
# autocorrect corrected водитель погрузчика-комплектовцик -> водитель погрузчика-комплектовщик
# autocorrect corrected главный ветеринарный врач рай сббж -> главный ветеринарный врач рай сабж
# autocorrect corrected слесарь по темонту тракторной техники -> слесарь по ремонту тракторной техники
# autocorrect corrected ответственный за опытные поля ягсха -> ответственный за опытные поля ясна
# autocorrect corrected пиццеол -> пиццей
# autocorrect corrected монтажник рэа и приборов -> монтажник ра и приборов
# autocorrect corrected монтажник рэа и приборов -> монтажник ра и приборов
# autocorrect corrected монтажник рэа и приборов -> монтажник ра и приборов
# autocorrect corrected ведущий инженер по пусконаладочные работы и шмр -> ведущий инженер по пусконаладочные работы и шар
# autocorrect corrected директор по агропроизводству -> директор по агропроизводство
# autocorrect corrected начальник скдладского хозяйства -> начальник складского хозяйства
# autocorrect corrected трактоврист-машинист -> тракторист-машинист
# autocorrect corrected миханизатор -> механизатор
# autocorrect corrected инженер-механик огм -> инженер-механик ом
# autocorrect corrected инденер -> инженер
# autocorrect corrected рыбообработчик -> рыбообработки
# autocorrect corrected упоковщик -> упаковщик
# autocorrect corrected начальник рмм -> начальник мм
# autocorrect corrected ветврач бактериолог-ветврач токсиколог-заведующий химико-токсикологичексим отделом -> ветврач бактериолог-ветврач токсиколог-заведующий химико-токсикологическим отделом
# autocorrect corrected оператор поломоечной машины -> оператор полномочной машины
# autocorrect corrected водитель бетонамешалки -> водитель бетономешалки
# autocorrect corrected инженер эксплуатации машинотракторного парка -> инженер эксплуатации машинотракторной парка
# autocorrect corrected машинист фронтального минипогрузчика -> машинист фронтального минипогрузчики
# autocorrect corrected тракторист-машинист трелевочника тдт -> тракторист-машинист трелёвочника тдт
# autocorrect corrected рабоий по производству мебели -> рабочий по производству мебели
# autocorrect corrected машинист автовышки агп- -> машинист автовышки ап-
# autocorrect corrected заведующий эпизоотическим отделом -> заведующий эпизоотических отделом
# autocorrect corrected ветеринарный врач – эпизоотолог красногоровской участковой лечебницы -> ветеринарный врач – эпизоотолог красногорской участковой лечебницы
# autocorrect corrected главный сспециалист поживотноводству -> главный специалист животноводству
# autocorrect corrected заместитель директора по логистике южного регионального отделеня -> заместитель директора по логистике южного регионального отделения
# autocorrect corrected автоэлектрик-диагност -> автоэлектрика-диагност
# autocorrect corrected арматуршик -> арматурщик
# autocorrect corrected инженер производства по г абакану -> инженер производства по г абакан
# autocorrect corrected мастер ремзоны -> мастер резоны
# autocorrect corrected ветеринарный врач эпизотолог -> ветеринарный врач эпизоотолог
# autocorrect corrected бухгалтер по учету тмц -> бухгалтер по учету тыц
# autocorrect corrected начальник атц -> начальник ат
# autocorrect corrected главный редактор медиаканала по совместительству с основной работой -> главный редактор медиаканал по совместительству с основной работой
# autocorrect corrected начальник птл -> начальник пол
# autocorrect corrected начальник свеклопункта -> начальник свеклопункт
# autocorrect corrected мастер призводственного участка -> мастер производственного участка
# autocorrect corrected руководитель научно-консультационного центра группы компаний югагрохим -> руководитель научно-консультационного центра группы компаний агрохим
# autocorrect corrected стрелок вохр -> стрелок вор
# autocorrect corrected о / у обэп инспектор обслуживания видеонабл специальный радио и офисной техники -> о / у обмп инспектор обслуживания видеозал специальный радио и офисной техники
# autocorrect corrected начальник беловского районного отдела филиала фгу "россельхозцентр" по курской области -> начальник бесовского районного отдела филиала югу "россельхозцентр" по курской области
# autocorrect corrected старший оператор колл-цеетра -> старший оператор колл-центра
# autocorrect corrected помошник машиниста экскаватора экг- -> помошник машиниста экскаватора кг-
# autocorrect corrected помошник машиниста экскаватора экг- -> помошник машиниста экскаватора кг-
# autocorrect corrected помошник машиниста экскаватора экг- -> помошник машиниста экскаватора кг-
# autocorrect corrected главный инжеенер -> главный инженер
# autocorrect corrected инженер неразрушающего кортроля -> инженер неразрушающего контроля
# autocorrect corrected инженер по наладке и испытаниям систем автоматического управления гпа -> инженер по наладке и испытаниям систем автоматического управления га
# autocorrect corrected машинист мтз- -> машинист муз-
# autocorrect corrected старщий инспектор -> старший инспектор
# autocorrect corrected "гостехнадзор" наманганской области -> "гостехнадзора" наманганской области
# autocorrect corrected секретарь молодожного союза и заместитель директора по делам молодежи -> секретарь молодёжного союза и заместитель директора по делам молодежи
# autocorrect corrected управляющий опх -> управляющий оп
# autocorrect corrected управляющий опх -> управляющий оп
# autocorrect corrected лаборант фитомониторинга -> лаборант биомониторинга
# autocorrect corrected слесарь мехцеха -> слесарь мехцех
# autocorrect corrected слесарь мехцеха -> слесарь мехцех
# autocorrect corrected слесарь мехцеха -> слесарь мехцех
# autocorrect corrected машинист агрегата для создания навивочных рукавов -> машинист агрегата для создания набивочных рукавов
# autocorrect corrected заместитель директора по растениеводствы и кормопроизводству -> заместитель директора по растениеводства и кормопроизводству
# autocorrect corrected аспрант кафедры растениеводства и селекции -> аспирант кафедры растениеводства и селекции
# autocorrect corrected инженер пдо -> инженер по
# autocorrect corrected заместитель директора по животнаводству -> заместитель директора по животноводству
# autocorrect corrected главный тхнолог -> главный технолог
# autocorrect corrected представитель гвэ на предприятии -> представитель гв на предприятии
# autocorrect corrected машинист подьемника каротажной станции -> машинист подъемника каротажной станции
# autocorrect corrected заведущего автогаража -> заведующего автогаража
# autocorrect corrected электромонтер-линейщик -> электромонтер-литейщик
# autocorrect corrected электромонтер-линейщик -> электромонтер-литейщик
# autocorrect corrected художник лтсо -> художник лесо
# autocorrect corrected художник лтсо -> художник лесо
# autocorrect corrected художник лтсо -> художник лесо
# autocorrect corrected автослесарь-арматуршик -> автослесарь-арматурщик
# autocorrect corrected экспертный консультант по развитию производсва -> экспертный консультант по развитию производства
# autocorrect corrected работник дпо -> работник по
# autocorrect corrected старший слесарь шиномонтожа -> старший слесарь шиномонтажа
# autocorrect corrected машинист агп -> машинист ап
# autocorrect corrected машинист автовышки агп- -> машинист автовышки ап-
# autocorrect corrected слсарь по ремонту оборудования -> слесарь по ремонту оборудования
# autocorrect corrected сервисный инжнер -> сервисный инженер
# autocorrect corrected специалист агроотдела -> специалист горотдела
# autocorrect corrected могтажник слаботочных систем -> монтажник слаботочных систем
# autocorrect corrected учередитель -> учредитель
# autocorrect corrected ландшафтное проектирование на договорной основе с квсо «фсб россии» -> ландшафтное проектирование на договорной основе с кво «фсб россии»
# autocorrect corrected бриадир -> бригадир
# autocorrect corrected машинист экскаватора погрузчики атек -> машинист экскаватора погрузчики атак
# autocorrect corrected тестовод -> тестовой
# autocorrect corrected ветеренарный врач -> ветеринарный врач
# autocorrect corrected машинист пдм -> машинист адм
# autocorrect corrected химик-хроматографист -> химик-хроматографии
# autocorrect corrected пробоотборщик гсм -> пробоотборник см
# autocorrect corrected монтажник-слоботочник -> монтажник-слоботчик
# autocorrect corrected монтажник-слоботочник -> монтажник-слоботчик
# autocorrect corrected заместитель генирального директора по производству -> заместитель генерального директора по производству
# autocorrect corrected начальник отдела асутп -> начальник отдела асуты
# autocorrect corrected заместитель начальника ообд -> заместитель начальника обод
# autocorrect corrected начальник картцентра -> начальник артцентр
# autocorrect corrected учебный мастер кабинет пэвм кафедры «автомобили и автомобильное хозяйство» -> учебный мастер кабинет эвм кафедры «автомобили и автомобильное хозяйство»
# autocorrect corrected водитель с допог -> водитель с дорог
# autocorrect corrected обвальщик / жиловщик -> обвальщик / силовик
# autocorrect corrected монтажник волс -> монтажник воли
# autocorrect corrected механизатор-эксковаторщик -> механизатор-экскаваторщик
# autocorrect corrected инженер эмтп -> инженер мтп
# autocorrect corrected производитель работ по спецработам -> производитель работ по спецработ
# autocorrect corrected инженер асутп -> инженер асуты
# autocorrect corrected механик слр -> механик ср
# autocorrect corrected гос инспектор по карантину растений в аркрым -> гос инспектор по карантину растений в крым
# autocorrect corrected главный зотехник -> главный зоотехник
# autocorrect corrected переработчик птицы и обвальщик птицы в обвалочном отделении убойно-перерабатывающего комплекса -> переработчик птицы и обвальщик птицы в балочном отделении убойно-перерабатывающего комплекса
# autocorrect corrected заведующий инкубаторием -> заведующий инкубаторе
# autocorrect corrected управляющая обвалочным цехом -> управляющая балочным цехом
# autocorrect corrected обрезчик-помощник бригадира -> образчик-помощник бригадира
# autocorrect corrected мастер обрезчик -> мастер образчик
# autocorrect corrected механик по автотраспорту -> механик по автотранспорту
# autocorrect corrected слесарь-поремонту автомобилей -> слесарь-ремонту автомобилей
# autocorrect corrected оператор асфальтоукладчика -> оператор асфальтоукладчики
# autocorrect corrected сервисный механик отдел горной-каръерной техники -> сервисный механик отдел горной-карьерной техники
# autocorrect corrected руководитель туруханского отдела ветеринарии -> руководитель туранского отдела ветеринарии
# autocorrect corrected тестовод пшеничных и элитных сортов хлеба -> тестовой пшеничных и элитных сортов хлеба
# autocorrect corrected веринарный врач -> тернарный врач
# autocorrect corrected оператор по искуственному осеменению птицы -> оператор по искусственному осеменению птицы
# autocorrect corrected панировщик -> планировщик
# autocorrect corrected тракторист эксковаторщик -> тракторист экскаваторщик
# autocorrect corrected машинистом расфасовочно-упаковочных машин -> машинистом расфасовано-упаковочных машин
# autocorrect corrected начальник свеклопункта -> начальник свеклопункт
# autocorrect corrected оператором расфасовочно-упаковочного автомата -> оператором расфасовано-упаковочного автомата
# autocorrect corrected начальник сббж-главный государственный ветеринарный инспектор на территории селижаровского района -> начальник сабж-главный государственный ветеринарный инспектор на территории селижаровского района
# autocorrect corrected машинист ппду -> машинист пуду
# autocorrect corrected начальник производственно-технологической лаборатории на оао степнянский элеватор" -> начальник производственно-технологической лаборатории на оао степанский элеватор"
# autocorrect corrected заместитель генерального директора по сельхозпроизводству -> заместитель генерального директора по сельхозпроизводства
# autocorrect corrected зоотехник племгруппы по сорочинскому району -> зоотехник племгруппы по сочинскому району
# autocorrect corrected сервисны инженер-механик -> сервисы инженер-механик
# autocorrect corrected заведующий ветпунктом булгаковского округа -> заведующий ветпункт булгаковского округа
# autocorrect corrected старший ветеринатный врач -> старший ветеринарный врач
# autocorrect corrected руководитель отдела продаж шпд и конвергентного продукта / менеджер по продажам конвергентного продукта -> руководитель отдела продаж пд и конвергентного продукта / менеджер по продажам конвергентного продукта
# autocorrect corrected заведующий ветпунктом -> заведующий ветпункт
# autocorrect corrected заместитель директора по ахч -> заместитель директора по ах
# autocorrect corrected инженер технического надзора за эц и асутп -> инженер технического надзора за эц и асуты
# autocorrect corrected директор тимского низового завода -> директор римского низового завода
# autocorrect corrected глава тимского района -> глава римского района
# autocorrect corrected глава администрации барковского сельского совета -> глава администрации банковского сельского совета

# %%
from collections import Counter

words = jobs_df['job_name_norm'].str.split().explode()

# Подсчитать частоту каждого слова
word_counts = Counter(words)

# Вывести самые частые слова
most_common_words = word_counts.most_common()

# Печать результатов
# print(most_common_words)

# %%
canon_perc = cfg["canon_job_names_top_percentile"]
apply_to_perc = cfg['try_to_find_canon_in_bottom_percentile']
if canon_perc < 0 or canon_perc > 100:
    print("WARNING: Wrong canon_job_names_top_percentile value in config.")
if apply_to_perc < 0 or apply_to_perc > 100:
    print("WARNING: Wrong try_to_find_canon_in_bottom_percentile value in config.")

# Нет смысла в пересечении нижнего и верхнего списка
if apply_to_perc + canon_perc > 100:
    print("WARNING: canon_job_names_top_percentile and try_to_find_canon_in_bottom_percentile values in config overlap.")

value_counts = jobs_df['job_name_norm'].value_counts()

top_quantive_value = 1 - canon_perc / 100
bottom_quantive_value = apply_to_perc / 100

# Определение порога для верхнего и нижнего n-процентилей
top_percent_threshold = value_counts.quantile(top_quantive_value)
bottom_percent_threshold = value_counts.quantile(bottom_quantive_value)

# Получение значений для верхнего и нижнего n-процентилей
bottom_percent_values = value_counts[value_counts <= bottom_percent_threshold].index
top_percent_values = set(value_counts[value_counts >= top_percent_threshold].index)

# Список строк, которые нужно удалить из top_percent_values
strings_to_remove = cfg["words_to_not_consider_as_canon_job_name"] + [" ", ""]

# Удаление строк из top_10_percent_values
top_percent_values -= set(strings_to_remove)

print("Rows taken into top-percentile values: ", len(top_percent_values))
print("Rows taken into bottom-percentile values: ", len(bottom_percent_values))

# Функция для проверки, содержит ли строка из нижнего процентиля все слова из какой-либо строки верхнего процентиля
def contains_all_words_from_top(bottom_value, top_values) -> list[str]:
    all_matches = []
    bottom_words = set(bottom_value.split())
    for top_value in top_values:
        top_words = set(top_value.split())
        if top_words.issubset(bottom_words):
            all_matches.append(top_value)

    return all_matches

words_to_explicitly_check = cfg["words_to_never_discard"]

# Итерация по строкам нижнего процентиля
for bottom_value in bottom_percent_values:
    all_matches = contains_all_words_from_top(bottom_value, top_percent_values)
    if all_matches:
        for i, match in enumerate(all_matches):
            for word in words_to_explicitly_check:
                if word in bottom_value and word not in match:
                    all_matches[i] = word + " " + match

    if not all_matches:
        continue

    # Выбрать лучший match из возможных (пока что по длинне строки)
    all_matches = sorted(all_matches, key=len, reverse=True)
    best_match = all_matches[0]
    if bottom_value != best_match:
        print(bottom_value + " -> " + best_match)
        print(all_matches)
        jobs_df['job_name_norm'] = jobs_df['job_name_norm'].replace(bottom_value, best_match)
# Out:
# Rows taken into top-percentile values:  374
# Rows taken into bottom-percentile values:  1670
# врач ветеринарный -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# мастер участка подготовки производства -> мастер участка
# ['мастер участка', 'мастер']
# сервисы инженер-механик -> инженер-механик
# ['инженер-механик']
# менеджер по продажам и работе с клиентами -> менеджер по работе с клиентами
# ['менеджер по работе с клиентами', 'менеджер по продажам', 'менеджер']
# инженер по холоду и климату -> инженер
# ['инженер']
# машинист погрузчика / оператор mac -> машинист погрузчика
# ['машинист погрузчика']
# специалист по продажам -> специалист
# ['специалист']
# начальник производства комбикормового завода -> начальник производства
# ['начальник производства']
# зоотехник племгруппы по сочинскому району -> зоотехник
# ['зоотехник']
# слесарь по обслуживанию и ремонту оборудования -> слесарь по ремонту оборудования
# ['слесарь по ремонту оборудования', 'слесарь']
# администратор ресепшен -> администратор
# ['администратор']
# инженер по эксплуатации холодильно-компрессорного оборудования -> инженер
# ['инженер']
# ведущий ветеринарный врач вет-сан эксперт -> ведущий ветеринарный врач
# ['ведущий ветеринарный врач', 'ведущий ветеринарный врач', 'ведущий врач ветеринарный', 'ведущий эксперт']
# ведущий специалист отдела животноводства -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# старший мастер отк -> старший мастер
# ['старший мастер']
# главный ветеринарный врач оп "бабынинское" -> главный ветеринарный врач
# ['главный ветеринарный врач', 'главный ветеринарный врач', 'главный врач ветеринарный']
# инженер по водоснабжению и канализации -> инженер
# ['инженер']
# оператор-наладчик линии производства металлопрофиля -> оператор-наладчик
# ['оператор-наладчик']
# руководитель агрономического отдела -> руководитель
# ['руководитель']
# начальник пекарного производства -> начальник производства
# ['начальник производства']
# заместитель директора по плодовым культурами -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# продавец-кассир хлебной зоны -> продавец-кассир
# ['продавец-кассир']
# менеджер по развитию бизнеса в области свиноводства -> менеджер по развитию бизнеса
# ['менеджер по развитию бизнеса', 'менеджер']
# ветеринарный специалист по свиноводству -> специалист
# ['специалист']
# менеджер по закупу -> менеджер
# ['менеджер']
# управляющий агроном -> агроном
# ['агроном']
# специалист зернового отдела -> специалист
# ['специалист']
# техник по воспроизводству стада -> техник
# ['техник']
# лабораторный техник -> техник
# ['техник']
# инструктор кинологической группы -> инструктор
# ['инструктор']
# лаборант по уходу за подопытными животными -> лаборант
# ['лаборант']
# начальник участка свинокомплекса -> начальник участка
# ['начальник участка']
# агроном по семеноводству -> агроном
# ['агроном']
# садовник озеленитель -> озеленитель
# ['озеленитель', 'садовник']
# специалист по запчастям сельхозтехники -> специалист
# ['специалист']
# специалист по технологии кормления -> специалист
# ['специалист']
# главный зоотехник по свиноводству -> главный зоотехник
# ['главный зоотехник', 'главный зоотехник']
# слесарь-ремонтник машино-тракторной бригады -> слесарь-ремонтник
# ['слесарь-ремонтник']
# инженер по ремонту тракторный парк -> инженер
# ['инженер']
# бригадир животноводческого хозяйства -> бригадир
# ['бригадир']
# технолог лос -> технолог
# ['технолог']
# дежурный электромонтер -> электромонтер
# ['электромонтер']
# ведущий специалист отдела имущества -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# бригадир смены -> бригадир
# ['бригадир']
# мастер смр -> мастер
# ['мастер']
# специалист по информационным технологиям -> специалист
# ['специалист']
# инженер механик по сервисному обслуживанию сельскохозяйственной техники и оборудования -> инженер механик
# ['инженер механик', 'механик', 'инженер']
# инженер по организации и нормированию труда -> инженер
# ['инженер']
# инженер по нормированию труда -> инженер
# ['инженер']
# инженер-технолог технологического бюро технического отдела -> инженер-технолог
# ['инженер-технолог']
# заместитель директора по административно-хозяйственной работе -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# заместитель директора по административно-хозяйственной части -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# инженер по снабжению отдела материально-технического обеспечения -> инженер по снабжению
# ['инженер по снабжению', 'инженер']
# мастер челябинского участка -> мастер участка
# ['мастер участка', 'мастер']
# инженер по эксплуатации зданий и оборудования -> инженер
# ['инженер']
# учебный мастер кабинет эвм кафедры «автомобили и автомобильное хозяйство» -> учебный мастер
# ['учебный мастер', 'мастер']
# руководитель ветеринарного отдела -> руководитель
# ['руководитель']
# лаборант кафедры "технология переработки продукции животноводства" -> лаборант
# ['лаборант']
# сервисный инженер атм -> сервисный инженер
# ['сервисный инженер', 'инженер']
# специалист по качеству -> специалист
# ['специалист']
# лаборант убойного цеха -> лаборант
# ['лаборант']
# инженер по стандартизации и сертификации -> инженер
# ['инженер']
# механик по ремонту и эксплуатации автотранспорта -> механик по ремонту автотранспорта
# ['механик по ремонту автотранспорта', 'механик']
# водитель а -> водитель
# ['водитель']
# водитель с дорог -> водитель
# ['водитель']
# технолог предприятия общественного питания -> технолог
# ['технолог']
# специалист по промышленной безопасности -> специалист
# ['специалист']
# инженер материально-технического снабжения -> инженер
# ['инженер']
# заместитель генерального директора по общим и коммерческим вопросам -> заместитель генерального директора
# ['заместитель генерального директора', 'заместитель директора', 'заместитель директора']
# исполнительный директор-главный инженер -> главный инженер
# ['главный инженер']
# агроном-семеновод агрохимик -> агроном-семеновод
# ['агроном-семеновод', 'агрохимик']
# специалист технической поддержки и ремонта техники и оборудования -> специалист
# ['специалист']
# старший мастер службы главного механика -> старший мастер
# ['старший мастер']
# механик цеха-главный механик фабрики -> главный механик
# ['главный механик']
# менеджер технолог -> менеджер
# ['менеджер', 'технолог']
# директор департамента -> директор
# ['директор']
# заведующий ветеринарным складом -> заведующий складом
# ['заведующий складом']
# механик технического оборудования -> механик
# ['механик']
# руководитель хозяйства -> руководитель
# ['руководитель']
# механик по ремонту и выпуску автотранспорта на линию -> механик по выпуску автотранспорта
# ['механик по выпуску автотранспорта', 'механик по ремонту автотранспорта', 'механик']
# агроном плодового питомника -> агроном
# ['агроном']
# начальник участка по ремонту и обслуживанию оборудования -> начальник участка
# ['начальник участка']
# агроном-технолог салатного отделения -> агроном-технолог
# ['агроном-технолог']
# менеджер проекта -> менеджер
# ['менеджер']
# менеджер по работе с персоналом -> менеджер
# ['менеджер']
# специалист коммерческого отдела -> специалист
# ['специалист']
# агроном по питанию растений в сооружениях защищенного грунта -> агроном
# ['агроном']
# младший лаборант -> лаборант
# ['лаборант']
# главный агроном научно-производственного отдела -> главный агроном
# ['главный агроном', 'главный агроном']
# главный специалист юридического отдела -> главный специалист
# ['главный специалист', 'главный специалист']
# заместитель генерального директора по сельхозпроизводства -> заместитель генерального директора
# ['заместитель генерального директора', 'заместитель директора', 'заместитель директора']
# продавец-консультант одежды -> продавец-консультант
# ['продавец-консультант']
# продавец-консультант ювелирных изделий -> продавец-консультант
# ['продавец-консультант']
# врио директора -> директора
# ['директора']
# мастер отделения подготовки сырья -> мастер
# ['мастер']
# инженер технический оборудования -> инженер
# ['инженер']
# специалист горотдела -> специалист
# ['специалист']
# заместитель директора по сельскому хозяйству -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# мастер ремонтно-механического участка -> мастер участка
# ['мастер участка', 'мастер']
# машинист бульдозера б- -> машинист бульдозера
# ['машинист бульдозера']
# инженер конструктор по электроснабжению -> инженер
# ['инженер']
# электромеханик участка -> электромеханик
# ['электромеханик']
# руководитель сервисной службы -> руководитель
# ['руководитель']
# инженер по эксплуатации автотранспорта -> инженер
# ['инженер']
# инженер по теплофикации сельскохозяйственного предприятия -> инженер
# ['инженер']
# мастер строительных и монтажных работ -> мастер
# ['мастер']
# инженер по эксплуатации сооружений и оборудования водопроводного и канализационного хозяйства -> инженер
# ['инженер']
# начальник цеха по производству комбикормов -> начальник цеха
# ['начальник цеха']
# заместитель директора по ах -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# главный специалист проекта -> главный специалист
# ['главный специалист', 'главный специалист']
# полевой эксперт по специальный культурам -> эксперт
# ['эксперт']
# мастер оросительных систем -> мастер
# ['мастер']
# зоотехник ферма -> зоотехник
# ['зоотехник']
# водитель категорий в -> водитель
# ['водитель']
# менеджер по продажам автомобилей -> менеджер по продажам
# ['менеджер по продажам', 'менеджер']
# тракторист-машинист широкого профиля -> тракторист-машинист
# ['тракторист-машинист']
# мастер по ремонту автотракторной техники -> мастер
# ['мастер']
# руководитель свиноводческой площадки -> руководитель
# ['руководитель']
# директор римского низового завода -> директор
# ['директор']
# технолог консультант -> технолог
# ['технолог']
# водитель автомобиля -> водитель
# ['водитель']
# механик кормоцеха -> механик
# ['механик']
# механик консервного завода -> механик
# ['механик']
# рабочий рыбовод -> рабочий
# ['рабочий']
# руководитель площадки крс -> руководитель
# ['руководитель']
# техник по племенному делу -> техник
# ['техник']
# мастер-приемщик слесарного цеха -> мастер-приемщик
# ['мастер-приемщик']
# инженер технического надзора за эц и асуты -> инженер
# ['инженер']
# руководитель подъезда и отъезда к воздушным судам -> руководитель
# ['руководитель']
# старший слесарь шиномонтажа -> старший слесарь
# ['старший слесарь']
# водитель разнорабочий -> разнорабочий
# ['разнорабочий', 'водитель']
# механик водитель -> водитель
# ['водитель', 'механик']
# личный семейный водитель -> водитель
# ['водитель']
# агроном отделении -> агроном
# ['агроном']
# менеджер по pr и рекламе -> менеджер по рекламе
# ['менеджер по рекламе', 'менеджер']
# ветеринарный врач отдела ветеринарно-санитарной безопасности -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# лаборант лаборатории перегонных систем автоматики и блокировки -> лаборант
# ['лаборант']
# техник службы асу тп и с -> техник
# ['техник']
# руководитель отдела продаж пд и конвергентного продукта / менеджер по продажам конвергентного продукта -> руководитель отдела продаж
# ['руководитель отдела продаж', 'менеджер отдела продаж', 'менеджер по продажам', 'руководитель', 'менеджер']
# грузчик отпускного цеха -> грузчик
# ['грузчик']
# заместитель директора по питанию -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# инженер по тракторам -> инженер
# ['инженер']
# руководитель отдела по работе с региональными клиентами -> руководитель
# ['руководитель']
# механик участка -> механик
# ['механик']
# менеджер по работе с снг -> менеджер
# ['менеджер']
# директор по развитию бизнеса -> директор
# ['директор']
# руководитель отдела продаж по россии и странам снг -> руководитель отдела продаж
# ['руководитель отдела продаж', 'руководитель']
# менеджер по закупкам и продажам -> менеджер по закупкам
# ['менеджер по закупкам', 'менеджер по продажам', 'менеджер']
# начальник участка кирпичного завода -> начальник участка
# ['начальник участка']
# контролер службы безопасности -> контролер
# ['контролер']
# ветеринарный врач службы ветеринарно-санитарного контроля -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# машинист экскаватора hyundai -> машинист экскаватора
# ['машинист экскаватора']
# машинист экскаватора погрузчика jsb -> машинист экскаватора
# ['машинист экскаватора', 'машинист погрузчика']
# механик упаковочного оборудования -> механик
# ['механик']
# руководитель отдела по борьбе с лейкозом крс ветврач-гематолог -> руководитель
# ['руководитель']
# ведущий специалист отдела строительства -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# инженер по новым машинам -> инженер
# ['инженер']
# ветеринарный врач станции -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# ветеринарный врач всэ -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# заместитель директора по селекции и семеноводству -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# заместитель директора по научному обеспечению семеноводства -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# ветеринарный врач откорма -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# механик тракторной технике -> механик
# ['механик']
# агроном цветовод -> агроном
# ['агроном']
# кладовщик распределительного центра -> кладовщик
# ['кладовщик']
# старший продавец отдела сад-техника -> старший продавец
# ['старший продавец']
# мастер кузовных работ -> мастер
# ['мастер']
# монтажник технологического оборудования и связанных с ним конструкций -> монтажник
# ['монтажник']
# тракторист дт -> тракторист
# ['тракторист']
# заместитель генерального директора по коммерческой деятельности -> заместитель генерального директора
# ['заместитель генерального директора', 'заместитель директора', 'заместитель директора']
# ведущий специалист отдела главного механика -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# заместитель директора по ахо -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# руководитель группы активных продаж -> руководитель
# ['руководитель']
# инженер по спецоборудованию спецтехники -> инженер
# ['инженер']
# агроном отдела защиты растений -> агроном
# ['агроном']
# бригадир отделения -> бригадир
# ['бригадир']
# монтажник стальных и железобетонных конструкций -> монтажник
# ['монтажник']
# грузчик продовольственной базы -> грузчик
# ['грузчик']
# диспетчер – администратор по настройке и обслуживанию орг техники -> администратор
# ['администратор']
# машинист экскаватора погрузчика тракторист -> машинист экскаватора
# ['машинист экскаватора', 'тракторист машинист', 'машинист погрузчика', 'тракторист']
# машинист экскаватора погрузчики атак -> машинист экскаватора
# ['машинист экскаватора']
# агроном участка -> агроном
# ['агроном']
# бригадир / заведующий складом -> заведующий складом
# ['заведующий складом', 'бригадир']
# техник структурированных кабельных систем -> техник
# ['техник']
# менеджер по логистике -> менеджер
# ['менеджер']
# инженер службы охранной сигнализации и спецсредств -> инженер
# ['инженер']
# специалист по страхованию -> специалист
# ['специалист']
# специалист по защите объектов интеллектуальной собственности -> специалист
# ['специалист']
# контролер ведомственной военизированной охраны -> контролер
# ['контролер']
# преподаватель ветеринарных дисциплин -> преподаватель
# ['преподаватель']
# менеджер по развитию территории -> менеджер
# ['менеджер']
# заместитель генерального директора по птицеводству -> заместитель генерального директора
# ['заместитель генерального директора', 'заместитель директора', 'заместитель директора']
# председатель спк -> председатель
# ['председатель']
# специалист по то -> специалист
# ['специалист']
# государственный инспектор пограничного ветеринарно-санитарного контроля на гос границе и транспорте -> государственный инспектор
# ['государственный инспектор']
# ведущий специалист кузовного производства -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# инженер по транспорту -> инженер
# ['инженер']
# начальник участка + агроном -> начальник участка
# ['начальник участка', 'агроном']
# заместитель директора по строительству -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# агроном технолог -> технолог
# ['технолог', 'агроном']
# дорожный мастер -> мастер
# ['мастер']
# руководитель туранского отдела ветеринарии -> руководитель
# ['руководитель']
# государственный ветеринарный инспектор по центральной группе районов -> государственный инспектор
# ['государственный инспектор']
# ведущий специалист по ценообразованию и строительному контролю -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# ведущий специалист сметно-договорного отдела -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# мастер по ремонту оборудования -> мастер
# ['мастер']
# механик цеха аммиачной селитры -> механик
# ['механик']
# инженер по автомаркету инженер по сервисному обслуживанию -> инженер
# ['инженер']
# начальник творожного цеха -> начальник цеха
# ['начальник цеха']
# администратор офиса -> администратор
# ['администратор']
# электромеханик по средствам автоматики и приборам технологического оборудования -> электромеханик
# ['электромеханик']
# мастер по ремонту компьютеров -> мастер
# ['мастер']
# заместитель директора по транспорту и логистике -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# мастер строительного участка -> мастер участка
# ['мастер участка', 'мастер']
# мастер по -> мастер
# ['мастер']
# инструктор кинолог -> инструктор
# ['инструктор']
# мастер отделочных работ -> мастер
# ['мастер']
# слесарь по ремонту грузовых автомобилей -> слесарь по ремонту автомобилей
# ['слесарь по ремонту автомобилей', 'слесарь']
# монтажник оборудования -> монтажник
# ['монтажник']
# главный инженер агропромышленного холдинга -> главный инженер
# ['главный инженер', 'главный инженер']
# инженер-технолог инновационного отдела -> инженер-технолог
# ['инженер-технолог']
# механик отдела эксплуатации -> механик
# ['механик']
# ветврач отделения совхоза -> ветврач
# ['ветврач']
# старший инструктор по вождению пожарных автомобилей -> старший инструктор
# ['старший инструктор']
# бригадир ферма -> бригадир
# ['бригадир']
# ведущий инженер группы транспортного обеспечения аппарата управления -> ведущий инженер
# ['ведущий инженер', 'ведущий инженер']
# доцент кафедры животноводства -> доцент
# ['доцент']
# менеджер диетолог -> менеджер
# ['менеджер']
# старший государственный инспектор референт -> старший государственный инспектор
# ['старший государственный инспектор']
# главный агроном и управляющий комбинатом -> главный агроном
# ['главный агроном', 'главный агроном']
# заведующий механик участка -> механик
# ['механик']
# руководитель проекта технологического оснащения производства -> руководитель
# ['руководитель']
# начальник цеха растениеводства -> начальник цеха
# ['начальник цеха']
# ветврач эпизоотолог -> ветврач
# ['ветврач']
# начальник отдела обеспечения производства -> начальник производства
# ['начальник производства']
# региональный руководитель -> руководитель
# ['руководитель']
# агроном и начальник цеха растениеводства -> начальник цеха
# ['начальник цеха', 'агроном']
# механик отдел сервиса строительной техники -> механик
# ['механик']
# сервисный механик отдел горной-карьерной техники -> механик
# ['механик']
# зоотехник молодняка -> зоотехник
# ['зоотехник']
# оператор-наладчик цеха по приготовлению комбикормов -> оператор-наладчик
# ['оператор-наладчик']
# мастер мясоперерабатывающего цеха -> мастер цеха
# ['мастер цеха', 'мастер']
# начальник цеха по приготовлению комбикормов -> начальник цеха
# ['начальник цеха']
# начальник сабж-главный государственный ветеринарный инспектор на территории селижаровского района -> главный государственный инспектор
# ['главный государственный инспектор']
# начальник ремонтно-механического цеха -> начальник цеха
# ['начальник цеха']
# слесарь по ремонту оборудования цеха аммиачной селитры -> слесарь по ремонту оборудования
# ['слесарь по ремонту оборудования', 'слесарь']
# администратор фитнес-клуба -> администратор
# ['администратор']
# руководитель проектов озеленение -> руководитель
# ['руководитель']
# специалист по мониторингу -> специалист
# ['специалист']
# специалист по справочникам -> специалист
# ['специалист']
# главный специалист по растениеводству -> главный специалист
# ['главный специалист', 'главный специалист']
# старший специалист по поддержки систем -> старший специалист
# ['старший специалист']
# руководитель департамента исследований и научно-технических разработок / владелец -> руководитель
# ['руководитель', 'владелец']
# научный руководитель проекта "протеин и корма" -> руководитель
# ['руководитель']
# начальник молочно-товарного комплекса по совместительству главный ветеринарный врач и главный зоотехник -> главный ветеринарный врач
# ['главный ветеринарный врач', 'главный ветеринарный врач', 'главный врач ветеринарный', 'главный зоотехник', 'главный зоотехник']
# заместитель директора по общим вопросам -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# научный руководитель заведующий производством главный технолог -> главный заведующий производством
# ['главный заведующий производством', 'главный руководитель', 'главный технолог', 'главный технолог']
# руководитель направления -> руководитель
# ['руководитель']
# руководитель проекта -> руководитель
# ['руководитель']
# начальник кранового участка -> начальник участка
# ['начальник участка']
# ведущий специалист по организации работы автотранспорта -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# преподаватель специальный дисциплин -> преподаватель
# ['преподаватель']
# механик флота -> механик
# ['механик']
# ветеринарный врач фермы -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# бригадир животноводческого комплекса -> бригадир
# ['бригадир']
# агроном по питанию и защите растений -> агроном по защите растений
# ['агроном по защите растений', 'агроном']
# региональный директор по продажам -> директор
# ['директор']
# агроном открытого грунта -> агроном
# ['агроном']
# ведущий ветеринарный специалист -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# руководитель отдела рекламы -> руководитель
# ['руководитель']
# агроном с совмещением управляющего -> агроном
# ['агроном']
# инженер по надзору за строительством -> инженер
# ['инженер']
# менеджер по продажам направление свиноводства -> менеджер по продажам
# ['менеджер по продажам', 'менеджер']
# инженер тракторный парк -> инженер
# ['инженер']
# инженер свеклоперерабатывающего цеха -> инженер
# ['инженер']
# главный агроном кластера -> главный агроном
# ['главный агроном', 'главный агроном']
# руководитель участка технической поддержки -> руководитель
# ['руководитель']
# специалист социологического опроса -> специалист
# ['специалист']
# механик и управляющий учебным хозяйством -> механик
# ['механик']
# менеджер по туризму -> менеджер
# ['менеджер']
# менеджер групповых проектов -> менеджер
# ['менеджер']
# менеджер продаж -> менеджер
# ['менеджер']
# главный зоотехник с обязанностями главный ветеринарного врача -> главный зоотехник
# ['главный зоотехник', 'главный зоотехник']
# начальник участка грузоподъемных механизмов -> начальник участка
# ['начальник участка']
# механик гпм -> механик
# ['механик']
# инженер по эксплуатации -> инженер
# ['инженер']
# машинист бульдозера cat d -> машинист бульдозера
# ['машинист бульдозера']
# ветеринарный врач в цехе разделки индейки -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# техник по учету материальных ценностей -> техник
# ['техник']
# тракторист механизатор широкого профиля -> механизатор
# ['механизатор', 'тракторист']
# тракторист экскаваторщик -> экскаваторщик
# ['экскаваторщик', 'тракторист']
# начальник исследовательской лаборатории -> начальник лаборатории
# ['начальник лаборатории']
# зоотехник по эффективному использованию комбикормов -> зоотехник
# ['зоотехник']
# начальник цеха свиноводства -> начальник цеха
# ['начальник цеха']
# менеджер отдела сбыта -> менеджер
# ['менеджер']
# бригадир озеленитель -> озеленитель
# ['озеленитель', 'бригадир']
# ведущий инженер по озеленению -> ведущий инженер
# ['ведущий инженер', 'ведущий инженер']
# руководитель отдела благоустройства и озеленения -> руководитель отдела озеленения
# ['руководитель отдела озеленения', 'руководитель']
# инженер асуты -> инженер
# ['инженер']
# производитель работ по спецработ -> производитель работ
# ['производитель работ']
# инженер механик производства -> инженер производства
# ['инженер производства', 'инженер механик', 'механик', 'инженер']
# специалист группы видеофиксации -> специалист
# ['специалист']
# старший специалист видеонаблюдения -> старший специалист
# ['старший специалист']
# оператор администратор -> администратор
# ['администратор']
# мастер по учету газа -> мастер
# ['мастер']
# специалист по организации работ вахтовым методом -> специалист
# ['специалист']
# начальник цеха репродукции -> начальник цеха
# ['начальник цеха']
# техник по ремонту и обслуживанию пивного оборудования -> техник
# ['техник']
# управляющий отделением " овощное " -> управляющий отделением
# ['управляющий отделением']
# начальник участка откорма -> начальник участка
# ['начальник участка']
# электромеханик по лифтам и эскалаторам -> электромеханик
# ['электромеханик']
# начальник цеха откорма -> начальник цеха
# ['начальник цеха']
# водитель эвакуатора -> водитель
# ['водитель']
# технолог по мясопереработке -> технолог
# ['технолог']
# главный специалист по зооинженерии -> главный специалист
# ['главный специалист', 'главный специалист']
# региональный представитель в санкт петербурге отдел птицеводческого оборудования -> региональный представитель
# ['региональный представитель']
# водитель на перевозке си -> водитель
# ['водитель']
# бригадир виноградарской бригады -> бригадир
# ['бригадир']
# бригадир птицеводческой бригады -> бригадир
# ['бригадир']
# резервный сторож -> сторож
# ['сторож']
# ведущий специалист по защите растений -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# тракторист / техник-механик -> тракторист
# ['тракторист']
# продавец не продовольственных товаров -> продавец
# ['продавец']
# механик ср -> механик
# ['механик']
# инженер по сельхоз технике -> инженер
# ['инженер']
# инженер электросвязи -> инженер
# ['инженер']
# директор обособленного подразделения -> директор
# ['директор']
# слесарь по ремонту сельхозтехники -> слесарь
# ['слесарь']
# монтажник воли -> монтажник
# ['монтажник']
# агроном оранжерейного комплекса -> агроном
# ['агроном']
# инженер по благоустройству -> инженер
# ['инженер']
# начальник смены участка -> начальник участка
# ['начальник участка', 'начальник смены']
# специалист договорного отдела -> специалист
# ['специалист']
# водитель автомобиля скорой помощи -> водитель
# ['водитель']
# главный ветеринарный врач агрофирмы -> главный ветеринарный врач
# ['главный ветеринарный врач', 'главный ветеринарный врач', 'главный врач ветеринарный']
# генеральный директор торгового дома -> генеральный директор
# ['генеральный директор', 'директор']
# заместитель директора по птицеводству -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# мастер холодильника -> мастер
# ['мастер']
# начальник участка разделки сырья -> начальник участка
# ['начальник участка']
# монтажник автоматика -> монтажник
# ['монтажник']
# ветеринарный врач молочно-товарной ферме -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# инженер мтп -> инженер
# ['инженер']
# заместитель директора по снабжению и сбыту -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# подземный механик по ремонту горно-шахтного оборудования -> механик
# ['механик']
# инженер по реализации сельскохозяйственной продукции -> инженер
# ['инженер']
# специалист отдела продаж -> специалист
# ['специалист']
# менеджер по развитию бизнеса в регионе центр -> менеджер по развитию бизнеса
# ['менеджер по развитию бизнеса', 'менеджер']
# наладчик оборудования цеха розлива-механик цеха-главный инженер -> главный инженер
# ['главный инженер']
# администратор сервисного центра -> администратор
# ['администратор']
# мастер по ремонту -> мастер
# ['мастер']
# сервисный инженер john deere -> сервисный инженер
# ['сервисный инженер', 'инженер']
# зональный ветеринарный врач -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# слесарь рту -> слесарь
# ['слесарь']
# инженер спортивных сооружений -> инженер
# ['инженер']
# мастер технологического отделений колбасного цеха -> мастер цеха
# ['мастер цеха', 'мастер']
# инженер по спецтехнике -> инженер
# ['инженер']
# специалист по поддержке продуктов -> специалист
# ['специалист']
# механик по автотранспорту -> механик
# ['механик']
# агроном селекционер -> агроном
# ['агроном']
# техник по ремонту и обслуживанию атракционов -> техник
# ['техник']
# мастер малярно-кузовного цеха -> мастер цеха
# ['мастер цеха', 'мастер']
# инженер по ремонту и эксплуатации тракторный парк -> инженер по эксплуатации тракторный парк
# ['инженер по эксплуатации тракторный парк', 'инженер']
# мастер образчик -> мастер
# ['мастер']
# директор по сельхоз развитию -> директор
# ['директор']
# главный специалист по компьютерному обеспечению -> главный специалист
# ['главный специалист', 'главный специалист']
# агроном управляющий -> агроном
# ['агроном']
# мастер основного производственного участка -> мастер производственного участка
# ['мастер производственного участка', 'мастер участка', 'мастер']
# старший механик строительного участка -> старший механик
# ['старший механик', 'старший механик']
# специалист отдела опороса -> специалист
# ['специалист']
# специалист по го чс и пожарной безопасности -> специалист
# ['специалист']
# агроном по питанию растений -> агроном
# ['агроном']
# старший агроном по капельному поливу -> старший агроном
# ['старший агроном', 'старший агроном']
# руководитель представительства -> руководитель
# ['руководитель']
# специалист по учету и контролю -> специалист
# ['специалист']
# главный агроном апк -> главный агроном
# ['главный агроном', 'главный агроном']
# генеральный директор ооо "новомихайловское" -> генеральный директор
# ['генеральный директор', 'директор']
# водитель диспетчер -> водитель
# ['водитель']
# технолог по заготовке сырья -> технолог
# ['технолог']
# менеджер внешнеэкономической деятельности -> менеджер
# ['менеджер']
# инженер по охране окружающей среды -> инженер
# ['инженер']
# руководитель зооветслужбы -> руководитель
# ['руководитель']
# водитель автотранспортного участка -> водитель
# ['водитель']
# инженер по эксплуатации сельскохозяйственных машин -> инженер
# ['инженер']
# ведущий ветеринарный врач по воспроизводству -> ведущий ветеринарный врач
# ['ведущий ветеринарный врач', 'ведущий ветеринарный врач', 'ведущий врач ветеринарный']
# водитель такси -> водитель
# ['водитель']
# специалист отдела информационно-технической поддержки -> специалист
# ['специалист']
# зоотехник по движению -> зоотехник
# ['зоотехник']
# системный администратор славянского участка ао «сварочно-монтажный трест» -> системный администратор
# ['системный администратор', 'администратор']
# начальник производственно-технологической лаборатории на оао степанский элеватор" -> начальник лаборатории
# ['начальник лаборатории']
# сер инженер -> инженер
# ['инженер']
# специалист по разделке мяса -> специалист
# ['специалист']
# торговый представитель отдела продаж -> торговый представитель
# ['торговый представитель']
# лаборант в лаборатории по производству лечебно-профилактических препаратов -> лаборант
# ['лаборант']
# директор автошколы -> директор
# ['директор']
# агроном бригады защиты растений -> агроном бригады
# ['агроном бригады', 'агроном']
# мастер сырьевого участка -> мастер участка
# ['мастер участка', 'мастер']
# ведущий агроном по питанию растений -> ведущий агроном
# ['ведущий агроном', 'ведущий агроном']
# заместитель генерального директора по общим вопросам -> заместитель генерального директора
# ['заместитель генерального директора', 'заместитель директора', 'заместитель директора']
# руководитель инкубатория -> руководитель
# ['руководитель']
# мастер деликатесного цеха -> мастер цеха
# ['мастер цеха', 'мастер']
# технолог рыбного цеха -> технолог
# ['технолог']
# механик токарь -> механик
# ['механик']
# инженер сигнализация и систем видеонаблюдения система контроля доступа и т д -> инженер
# ['инженер']
# тракторист полеводства -> тракторист
# ['тракторист']
# сменный механик -> механик
# ['механик']
# менеджер по продаже недвижимости -> менеджер
# ['менеджер']
# руководитель группы оцифровки и электронного архива -> руководитель
# ['руководитель']
# механик отдела технического обслуживания -> механик
# ['механик']
# руководитель по воспроизводству -> руководитель
# ['руководитель']
# директор завода -> директор
# ['директор']
# главный технолог департамента -> главный технолог
# ['главный технолог', 'главный технолог']
# технолог переработки молока -> технолог
# ['технолог']
# агроном открытого и закрытого грунта -> агроном
# ['агроном']
# технолог по выращиванию -> технолог
# ['технолог']
# начальник участка племенного и откормочного поголовья -> начальник участка
# ['начальник участка']
# начальник участка доращивания и откорма -> начальник участка откорма и доращивания
# ['начальник участка откорма и доращивания', 'начальник участка']
# агроном органа инспекции -> агроном
# ['агроном']
# агроном защиты растений -> агроном
# ['агроном']
# контролер зернового производства -> контролер
# ['контролер']
# инженер-механик ом -> инженер-механик
# ['инженер-механик']
# инженер по импортной технике -> инженер
# ['инженер']
# инженер по запасным частям -> инженер
# ['инженер']
# менеджер по продажам запасных частей -> менеджер по продажам
# ['менеджер по продажам', 'менеджер']
# механик транспортного департамента -> механик
# ['механик']
# заместитель главного ветеринарного врача комбината -> заместитель главного ветеринарного врача
# ['заместитель главного ветеринарного врача', 'заместитель главного ветеринарного врача', 'заместитель главного врача']
# главный ветеринарный врач города орша -> главный ветеринарный врач
# ['главный ветеринарный врач', 'главный ветеринарный врач', 'главный врач ветеринарный']
# менеджер по работе с ключевыми клиентами -> менеджер по работе с клиентами
# ['менеджер по работе с клиентами', 'менеджер']
# техник объективного контроля -> техник
# ['техник']
# начальник цеха животноводства -> начальник цеха
# ['начальник цеха']
# тракторист категории "с" погрузчик -> тракторист
# ['тракторист']
# техник кафедры химии и защиты растений -> техник
# ['техник']
# ведущий специалист эксперт -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист', 'ведущий эксперт']
# слесарь по ремонту сельскохозяйственной машин и оборудования -> слесарь по ремонту оборудования
# ['слесарь по ремонту оборудования', 'слесарь']
# командир отделения обеспечения инженерно-саперного батальона -> командир отделения
# ['командир отделения']
# начальник механосборочного участка -> начальник участка
# ['начальник участка']
# инженер проблемная лаборатория аквакультур -> инженер
# ['инженер']
# руководитель проектов -> руководитель
# ['руководитель']
# директор регионального представительства -> директор
# ['директор']
# менеджер по продажам автозапчастей -> менеджер по продажам
# ['менеджер по продажам', 'менеджер']
# менеджер отдела снабжения -> менеджер
# ['менеджер']
# инженер отдела ремонта и эксплуатации техники животноводства -> инженер
# ['инженер']
# мясокомбинат илишмясо главный технолог -> главный технолог
# ['главный технолог', 'главный технолог']
# поставки пищевых ингредиентов региональный менеджер -> региональный менеджер
# ['региональный менеджер', 'менеджер']
# предприятие питания заведующий производством -> заведующий производством
# ['заведующий производством']
# заместитель директора сельскохозяйственного департамента -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# главный специалист агрономического отдела -> главный специалист
# ['главный специалист', 'главный специалист']
# главный специалист по технологиям питания и защиты растений -> главный специалист
# ['главный специалист', 'главный специалист']
# директор по работе с клиентами -> директор
# ['директор']
# мастер цеха сварочных металлоконструкций -> мастер цеха
# ['мастер цеха', 'мастер']
# специалист сервисно-монтажной службы -> специалист
# ['специалист']
# инженер управления эксплуатации -> инженер
# ['инженер']
# руководитель службы растениеводства -> руководитель
# ['руководитель']
# ветврач бактериолог-ветврач токсиколог-заведующий химико-токсикологическим отделом -> ветврач
# ['ветврач']
# заведующий лабораторией-зам главный ветврача-гл ветврач -> главный ветврач
# ['главный ветврач', 'главный ветврач']
# специалист сервиса и монтажа -> специалист
# ['специалист']
# помощник бригадира овощеводческой бригады -> помощник бригадира
# ['помощник бригадира']
# бригадир полеводческой бригады -> бригадир
# ['бригадир']
# специалист по земельным вопросам -> специалист
# ['специалист']
# региональный представитель по курганской и тюменской областям -> региональный представитель
# ['региональный представитель']
# зоотехник управляющий отделением -> управляющий отделением
# ['управляющий отделением', 'зоотехник']
# старший мастер комбикормового завода -> старший мастер
# ['старший мастер']
# главный инженер комбикормового завода -> главный инженер
# ['главный инженер', 'главный инженер']
# механик отдела технического контроля -> механик
# ['механик']
# механик по выпуску автомобилей -> механик
# ['механик']
# ветеринарный врач племенной фермы крс -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# технолог глубокой переработки -> технолог
# ['технолог']
# сварщик контактной сварки -> сварщик
# ['сварщик']
# менеджер по поиску клиентов -> менеджер
# ['менеджер']
# менеджер товароучета и хранения -> менеджер
# ['менеджер']
# заведующий складом в магазине одежды -> заведующий складом
# ['заведующий складом']
# главный механик производства -> главный механик
# ['главный механик', 'главный механик']
# сервисный инженер технический поддержки клиентов по средней азии -> сервисный инженер
# ['сервисный инженер', 'инженер']
# рабочий по производству мебели -> рабочий
# ['рабочий']
# главный агрохимик района -> главный агрохимик
# ['главный агрохимик']
# инженер по производству -> инженер
# ['инженер']
# инженер-механик энергомеханический участок -> инженер-механик
# ['инженер-механик']
# тракторист-машинист трелёвочника тдт -> тракторист-машинист
# ['тракторист-машинист']
# продавец-консультант автозапчастей -> продавец-консультант
# ['продавец-консультант']
# инженер эксплуатации машинотракторной парка -> инженер
# ['инженер']
# инженер-механик начальник производственной базы -> инженер-механик
# ['инженер-механик']
# менеджер отдела логистики -> менеджер
# ['менеджер']
# водитель бетономешалки -> водитель
# ['водитель']
# инженер пл эксплуатации техники -> инженер
# ['инженер']
# специалист участка -> специалист
# ['специалист']
# водитель всех марок автомобилей -> водитель
# ['водитель']
# директор по развитию -> директор
# ['директор']
# агроном-технолог тепличного комплекса -> агроном-технолог
# ['агроном-технолог']
# начальник животноводческого комплекса граворново -> начальник животноводческого комплекса
# ['начальник животноводческого комплекса']
# экономист отдела труда и зарплаты -> экономист
# ['экономист']
# инженер по производственным процессам -> инженер
# ['инженер']
# инженер по развитию -> инженер
# ['инженер']
# специалист по логистике и коммерческой деятельности -> специалист по логистике
# ['специалист по логистике', 'специалист']
# менеджер по закупке зерновых и масличных культур -> менеджер
# ['менеджер']
# сервис инженер -> инженер
# ['инженер']
# ведущий специалист группы поддержки пользователей и сопровождение платежных систем -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# рабочий по обследованию растений -> рабочий
# ['рабочий']
# механик по ремонту основного и вспомогательного технологического оборудования -> механик
# ['механик']
# водитель бензовоза всех категорий -> водитель бензовоза
# ['водитель бензовоза', 'водитель']
# машинист экскаватора а -> машинист экскаватора
# ['машинист экскаватора']
# мастер экспериментального цеха -> мастер цеха
# ['мастер цеха', 'мастер']
# участковый ветеринарный врач -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# стропальщик по выгрузке и отгрузке пиломатерьялов -> стропальщик
# ['стропальщик']
# механик арматурного цеха -> механик
# ['механик']
# механик по закупке запчастей -> механик
# ['механик']
# мастер сварочного участка -> мастер участка
# ['мастер участка', 'мастер']
# директор мясокомбината -> директор
# ['директор']
# заместитель генерального директора / начальник производства -> заместитель генерального директора
# ['заместитель генерального директора', 'заместитель начальник производства', 'заместитель директора', 'заместитель директора']
# ведущий агроном отдела защиты растений -> ведущий агроном
# ['ведущий агроном', 'ведущий агроном']
# сервисный инженер-механик -> инженер-механик
# ['инженер-механик']
# зоотехник норковой фермы -> зоотехник
# ['зоотехник']
# бригадир садово-ягодной бригады -> бригадир
# ['бригадир']
# председатель колхоза -> председатель
# ['председатель']
# менеджер торгового зала -> менеджер
# ['менеджер']
# зоотехник-по кормам до заместитель директора по производству -> заместитель директора по производству
# ['заместитель директора по производству', 'заместитель директора', 'заместитель директора']
# руководитель департамента кормов -> руководитель
# ['руководитель']
# специалист отдела промышленности и инфраструктуры -> специалист
# ['специалист']
# инженер механик " материально технической базы" -> инженер механик
# ['инженер механик', 'механик', 'инженер']
# технический специалист дорожно-строительной техники -> технический специалист
# ['технический специалист', 'специалист']
# помощник директора по хозяйство -> директора
# ['директора']
# инженер по ведению технологического процесса -> инженер
# ['инженер']
# бухгалтер по заработной плате -> бухгалтер
# ['бухгалтер']
# руководитель проекта создания питомника декоративных культур -> руководитель
# ['руководитель']
# руководитель магазина продажа с\х запчастей г искити -> руководитель
# ['руководитель']
# сменный мастер -> мастер
# ['мастер']
# руководитель испытательного центра -> руководитель
# ['руководитель']
# территориальный директор элеватора -> директор
# ['директор']
# руководитель элеватора -> руководитель
# ['руководитель']
# руководитель производства -> руководитель
# ['руководитель']
# ведущий инженер по сертификации -> ведущий инженер
# ['ведущий инженер', 'ведущий инженер']
# заместитель исполнительного директора комбикормового завода -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# специалист по переговорам -> специалист
# ['специалист']
# инженер по оформлению таможенной документации -> инженер
# ['инженер']
# бригадир фермы -> бригадир
# ['бригадир']
# слесарь нефтепромыслового оборудования -> слесарь
# ['слесарь']
# менеджер по молочным продуктам -> менеджер
# ['менеджер']
# повар холодного цеха -> повар
# ['повар']
# ветеринарный врач молодняка -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# тракторист-машинист экскаваторщик -> тракторист-машинист
# ['тракторист-машинист', 'экскаваторщик']
# бригадир технического сервиса -> бригадир
# ['бригадир']
# менеджер по железной дороге с дальнейшим повышением до технического директора -> директора
# ['директора', 'менеджер']
# инженер-механик открытого грунта -> инженер-механик
# ['инженер-механик']
# мастер по оборудованию -> мастер
# ['мастер']
# мастер по ремонту цехового оборудования -> мастер
# ['мастер']
# начальник комбикормового цеха -> начальник цеха
# ['начальник цеха']
# главный специалист по производству -> главный специалист
# ['главный специалист', 'главный специалист']
# заместитель директора по координации работы инженерно-технических служб -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# инженер отк -> инженер
# ['инженер']
# мастер приемщик -> мастер
# ['мастер']
# инженер по гарантии -> инженер
# ['инженер']
# механик автоколонны -> механик
# ['механик']
# управляющий отделением садовой бригады -> управляющий отделением
# ['управляющий отделением']
# зоотехник цеха инкубации -> зоотехник
# ['зоотехник']
# тракторист водитель погрузчика -> водитель погрузчика
# ['водитель погрузчика', 'тракторист', 'водитель']
# электромонтер по монтажу и обслуживанию лэп -> электромонтер
# ['электромонтер']
# инженер по пусконаладочные работы -> инженер
# ['инженер']
# ведущий инженер по пусконаладочные работы и шар -> ведущий инженер
# ['ведущий инженер', 'ведущий инженер']
# специалист технической поддержки отдела продаж -> специалист
# ['специалист']
# специалист по контролю качества -> специалист
# ['специалист']
# специалист по сопровождению сельскохозяйственных предприятий -> специалист
# ['специалист']
# специалист пресс-службы -> специалист
# ['специалист']
# руководитель "центра репродукции -> руководитель
# ['руководитель']
# формовщик колбасных изделий -> формовщик
# ['формовщик']
# заместитель директора по науке -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# агроном овощеводческого и зернового производства -> агроном
# ['агроном']
# агроном территории -> агроном
# ['агроном']
# тракторист к- -> тракторист
# ['тракторист']
# финансовый менеджер -> менеджер
# ['менеджер']
# водитель фронтального погрузчика т -> водитель погрузчика
# ['водитель погрузчика', 'водитель']
# ведущий специалист отдела организации противоэпизоотических мероприятий -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# техник асу тп -> техник
# ['техник']
# директор по агропроизводство -> директор
# ['директор']
# главный технолог мельничного производства -> главный технолог
# ['главный технолог', 'главный технолог']
# инженер по запуску в эксплуатацию и обслуживанию оборудования -> инженер
# ['инженер']
# водитель фронтального погрузчика -> водитель погрузчика
# ['водитель погрузчика', 'водитель']
# контролер кпп -> контролер
# ['контролер']
# командир отделения мотористов -> командир отделения
# ['командир отделения']
# механик главный инжинер -> главный механик
# ['главный механик', 'главный механик']
# главный ветеринарный врач рай сабж -> главный ветеринарный врач
# ['главный ветеринарный врач', 'главный ветеринарный врач', 'главный врач ветеринарный']
# инженер реализации проектов -> инженер
# ['инженер']
# личный водитель -> водитель
# ['водитель']
# водитель погрузчика-комплектовщик -> водитель
# ['водитель']
# руководитель хозяйственно-ландшафтной службы -> руководитель
# ['руководитель']
# заместитель генерального директора по транспортно-складскому хоз-ву -> заместитель генерального директора
# ['заместитель генерального директора', 'заместитель директора', 'заместитель директора']
# продавец-консультант непродовольственных товаров -> продавец-консультант
# ['продавец-консультант']
# управляющий ветеринарный врач -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# технолог-старший мастер -> старший мастер
# ['старший мастер']
# механик цеха ячеистого бетона -> механик
# ['механик']
# преподаватель кафедры ремонта машин -> преподаватель
# ['преподаватель']
# мл научный сотрудник каф селекции и семеноводства полевых культур -> научный сотрудник
# ['научный сотрудник']
# ведущий специалист департамента закупок -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# руководитель обособленного подразделения -> руководитель подразделения
# ['руководитель подразделения', 'руководитель']
# руководитель проектов по растениеводству -> руководитель
# ['руководитель']
# заместитель главного агронома агрохолдинга «авангард-агро» -> заместитель главного агронома
# ['заместитель главного агронома']
# слесарь по ремонту тракторной техники -> слесарь
# ['слесарь']
# преподаватель пдд -> преподаватель
# ['преподаватель']
# ветеринарный врач родильного отделения -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# техник водоподготовки -> техник
# ['техник']
# мастер заправка -> мастер
# ['мастер']
# территориальный менеджер -> менеджер
# ['менеджер']
# преподаватель технических дисциплин -> преподаватель
# ['преподаватель']
# сотрудник службы охраны машинист-тракторист зерноуборочных комбайнов слесарь сборочного цеха -> слесарь
# ['слесарь']
# слесарь по ремонту автомобилей и мотоциклов -> слесарь по ремонту автомобилей
# ['слесарь по ремонту автомобилей', 'слесарь']
# агроном инспектор -> агроном
# ['агроном']
# исполнительный директор по производству -> директор по производству
# ['директор по производству', 'исполнительный директор', 'директор']
# заместитель директора по растениеводства и кормопроизводству -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# мастер котельной -> мастер
# ['мастер']
# инженер по эксплуатации теплотехнического оборудования -> инженер
# ['инженер']
# ведущий инженер-теплотехник по учету энергоресурсов -> ведущий инженер-теплотехник
# ['ведущий инженер-теплотехник']
# специалист по продажам банковских продуктов -> специалист
# ['специалист']
# ветеринарный фельдшер начальник станции исскуственного осеменения и заместитель управляющего комплекса -> заместитель ветеринарный фельдшер
# ['заместитель ветеринарный фельдшер']
# менеджер оптового отдела продаж -> менеджер отдела продаж
# ['менеджер отдела продаж', 'менеджер']
# мастер участка заморозки мпп -> мастер участка
# ['мастер участка', 'мастер']
# мастер участка бескостной группы -> мастер участка
# ['мастер участка', 'мастер']
# инженер-механик технологического оборудования -> инженер-механик
# ['инженер-механик']
# ...
# ['ветеринарный врач', 'врач ветеринарный']
# кладовщик склада готовой продукции -> кладовщик
# ['кладовщик']
# кладовщик по браку -> кладовщик
# ['кладовщик']
# лаборант биомониторинга -> лаборант
# ['лаборант']
# инженер по эксплуатации оборудования -> инженер
# ['инженер']
# электро механик -> механик
# ['механик']
# ведущий специалист отдела земледелия -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# агроном отдела -> агроном
# ['агроном']
# старший инженер сельскохозяйственной группы -> старший инженер
# ['старший инженер', 'старший инженер']
# заместитель директора по растениеводству -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# руководитель департамента науки и инновационного развития -> руководитель
# ['руководитель']
# агроном консультант-менеджер -> агроном
# ['агроном']
# агроном хозяйство -> агроном
# ['агроном']
# агроном и управляющий хозяйство -> управляющий хозяйство
# ['управляющий хозяйство', 'агроном']
# электрик в отдел эксплуатации -> электрик
# ['электрик']
# начальник смены службы охрана -> начальник смены
# ['начальник смены']
# рабочий по комплексному обслуживанию производства -> рабочий
# ['рабочий']
# слесарь по снабжению -> слесарь
# ['слесарь']
# механик гаража -> механик
# ['механик']
# водитель в отдел эксплуатации -> водитель
# ['водитель']
# руководитель площадки откорма бройлеров -> руководитель
# ['руководитель']
# агроном подразделения -> агроном
# ['агроном']
# мастер энергоцеха -> мастер
# ['мастер']
# начальник службы безопасности и охраны -> начальник службы безопасности
# ['начальник службы безопасности']
# механик по техническому контролю -> механик
# ['механик']
# мастер участка малой механизации -> мастер участка
# ['мастер участка', 'мастер']
# электромонтер по обслуживанию пс -> электромонтер
# ['электромонтер']
# механик мастерской -> механик
# ['механик']
# директор мясоперерабатывающего предприятия -> директор
# ['директор']
# директор производства -> директор
# ['директор']
# охранник группы быстрого реагирования -> охранник
# ['охранник']
# специалист по работе с клиентами справочно-правовой системы гарант -> специалист по работе с клиентами
# ['специалист по работе с клиентами', 'специалист']
# старший преподаватель кафедры ветеринарии -> старший преподаватель
# ['старший преподаватель']
# ветеринарный врач инкубатория -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# ветеринарный врач в отделе производственно-ветеринарного контроля и управления качеством осп "завод по убою и переработке индейки" -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# механик автогаража -> механик
# ['механик']
# инженер отдела сбыта -> инженер
# ['инженер']
# водитель-экспедитор категория е на рефрижераторе -> водитель-экспедитор
# ['водитель-экспедитор']
# преподаватель правил дорожного движения -> преподаватель
# ['преподаватель']
# инструктор по обучению вождения -> инструктор
# ['инструктор']
# помощник лесничего мастер леса -> мастер леса
# ['мастер леса', 'мастер']
# государственный ветеринарный врач -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# государственный ветеринарный инспектор фс -> государственный инспектор
# ['государственный инспектор']
# начальник производственно-технологической лаборатории -> начальник лаборатории
# ['начальник лаборатории']
# специалист по заказ-нарядам -> специалист
# ['специалист']
# региональный менеджер по продажам сельско-хозяйственной техники -> региональный менеджер по продажам
# ['региональный менеджер по продажам', 'региональный менеджер', 'менеджер по продажам', 'менеджер']
# помощник руководителя фирмы -> помощник руководителя
# ['помощник руководителя']
# главный специалист службы сборки и доставки офисной мебели -> главный специалист
# ['главный специалист', 'главный специалист']
# менеджер регионального сбыта -> менеджер
# ['менеджер']
# руководитель отдела доставки и сборки мебели -> руководитель
# ['руководитель']
# электрик по обслуживанию слаботочных систем -> электрик
# ['электрик']
# механик тяжелой техники -> механик
# ['механик']
# механик авто гаража -> механик
# ['механик']
# специалист по сопровождению по -> специалист
# ['специалист']
# менеджер по снабжению -> менеджер
# ['менеджер']
# старший инженер отдела вт -> старший инженер
# ['старший инженер', 'старший инженер']
# технический руководитель -> руководитель
# ['руководитель']
# менеджер по эксплуатации транспортных средств -> менеджер
# ['менеджер']
# бригадир ветсанбригады -> бригадир
# ['бригадир']
# консультант по животноводству первой категории -> консультант по животноводству
# ['консультант по животноводству']
# главный технолог животноводческого комплекса -> главный технолог
# ['главный технолог', 'главный технолог']
# заместитель генерального директора по животноводству / главный ветеринарный врач комплекса -> главный заместитель директора по животноводству
# ['главный заместитель директора по животноводству', 'главный заместитель генерального директора', 'заместитель главный ветеринарный врач', 'главный заместитель директора', 'заместитель ветеринарный врач', 'заместитель врач ветеринарный', 'заместитель директора']
# главный ветеринарный врач холдинга -> главный ветеринарный врач
# ['главный ветеринарный врач', 'главный ветеринарный врач', 'главный врач ветеринарный']
# главный специалист отдела благоустройства и реконструкции -> главный специалист
# ['главный специалист', 'главный специалист']
# ведущий инженер отдела благоустройства -> ведущий инженер
# ['ведущий инженер', 'ведущий инженер']
# специалист по благоустройству и развитию городской среды -> специалист по благоустройству
# ['специалист по благоустройству', 'специалист']
# главный эксперт отдела по работе с проблемными активами -> главный эксперт
# ['главный эксперт']
# инженер технического надзора -> инженер
# ['инженер']
# кладовщик неофициально -> кладовщик
# ['кладовщик']
# зоотехник фуражир -> зоотехник
# ['зоотехник']
# агроном тепличного комплекса -> агроном
# ['агроном']
# агроном полевой бригады -> агроном бригады
# ['агроном бригады', 'агроном']
# инженер по ремонту и эксплуатации тракторов и сельскохозяйственных агрегатов -> инженер
# ['инженер']
# лаборант всэ -> лаборант
# ['лаборант']
# командир отделения взвода артиллерийской разведки -> командир отделения
# ['командир отделения']
# старший технолог мясоперерабатывающего цеха -> старший технолог
# ['старший технолог']
# водитель-экспедитор малотоннажного специализированного автотранспорта -> водитель-экспедитор
# ['водитель-экспедитор']
# менеджер ахо -> менеджер
# ['менеджер']
# инженер по эксплуатации сельскохозяйственной машин -> инженер
# ['инженер']
# механик автотранспортного парка -> механик
# ['механик']
# старший инженер по механизации -> старший инженер
# ['старший инженер', 'старший инженер']
# техник сигнализация и видеонаблюдения -> техник
# ['техник']
# бухгалтер по учету тыц -> бухгалтер
# ['бухгалтер']
# начальник строительного участка -> начальник участка
# ['начальник участка']
# бригадир отдела кормопроизводство -> бригадир
# ['бригадир']
# главный ветврач хозяйства -> главный ветврач
# ['главный ветврач', 'главный ветврач']
# специалист по дезинфекции -> специалист
# ['специалист']
# менеджер по качеству -> менеджер
# ['менеджер']
# руководитель медицина -> руководитель
# ['руководитель']
# государственный инспектор отдела государственного внутреннего ветеринарного надзора -> государственный инспектор
# ['государственный инспектор']
# заведующий отделом герпетологии -> заведующий отделом
# ['заведующий отделом']
# инженер по трудоемким процессам -> инженер
# ['инженер']
# командир отделения начальник передвижной радиостанции внештатный техник батареи -> командир отделения
# ['командир отделения', 'техник']
# мастер резоны -> мастер
# ['мастер']
# механик по ремонту -> механик
# ['механик']
# инженер производства по г абакан -> инженер производства
# ['инженер производства', 'инженер']
# заместитель директора по внешним связям -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# комплектовщик! укладчик-упаковщик -> укладчик-упаковщик
# ['укладчик-упаковщик']
# начальник колонны дорожно-строительной техники и автомобильного транспорта -> начальник колонны
# ['начальник колонны']
# производственный директор -> директор
# ['директор']
# специалист по кормлению животных -> специалист
# ['специалист']
# инженер по эксплуатации сельхоз / техники -> инженер
# ['инженер']
# инженер по эксплуатации и ремонту тракторный парк -> инженер по эксплуатации тракторный парк
# ['инженер по эксплуатации тракторный парк', 'инженер']
# специалист по обработке янтаря -> специалист
# ['специалист']
# механик транспортного участка -> механик
# ['механик']
# заведующий лабораторией растениеводства -> заведующий лабораторией
# ['заведующий лабораторией']
# региональный торговый представитель -> региональный представитель
# ['региональный представитель', 'торговый представитель']
# ветеринарный врач фермы № -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# ведущий специалист отдела надзора за обеспечением здоровья животных и переданных полномочий службы по ветеринарному надзору красноярского края -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# менеджер по запчастям -> менеджер
# ['менеджер']
# заместитель директора по логистике южного регионального отделения -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# главный специалист животноводству -> главный специалист
# ['главный специалист', 'главный специалист']
# ветеринарный врач – эпизоотолог красногорской участковой лечебницы -> ветеринарный врач эпизоотолог
# ['ветеринарный врач эпизоотолог', 'ветеринарный врач', 'врач ветеринарный']
# ветеринарный врач комплексной животноводческой фермы -> ветеринарный врач
# ['ветеринарный врач', 'врач ветеринарный']
# ведущий врач ветеринарной медицины эпизоотического отдела -> ведущий врач ветеринарной медицины
# ['ведущий врач ветеринарной медицины']
# директор донецкой областной государственной лаборатории ветеринарной медицины -> директор
# ['директор']
# директор донецкой региональной государственной лаборатории ветеринарной медицины -> директор
# ['директор']
# заведующий эпизоотических отделом -> заведующий отделом
# ['заведующий отделом']
# заведующий производственной лабораторией мясокомбината частного акционерного общества «апк-инвест» -> заведующий лабораторией
# ['заведующий лабораторией']
# главный ветеринарный врач колхоза -> главный ветеринарный врач
# ['главный ветеринарный врач', 'главный ветеринарный врач', 'главный врач ветеринарный']
# агроном химик -> агроном
# ['агроном']
# менеджер по продаже запчастей -> менеджер
# ['менеджер']
# студент специалист -> специалист
# ['специалист', 'студент']
# агроном по саду -> агроном
# ['агроном']
# лаборант в отделе ягодных культур -> лаборант
# ['лаборант']
# заведующий противоэпизоотологическим отделом -> заведующий отделом
# ['заведующий отделом']
# рабочий по защите растений -> рабочий
# ['рабочий']
# бригадир растениеводства -> бригадир
# ['бригадир']
# рабочий по химической защите растений -> рабочий
# ['рабочий']
# слесарь по ремонту технологического оборудования -> слесарь по ремонту оборудования
# ['слесарь по ремонту оборудования', 'слесарь']
# механик бригады -> механик
# ['механик']
# инженер по эксплуатации тракторного парка и сельскохозяйственной оборудования -> инженер
# ['инженер']
# заведующий гаражом и заведующий машинно-тракторной мастерской -> заведующий гаражом
# ['заведующий гаражом']
# механик по ремонту и выпуску тяжелой технике -> механик
# ['механик']
# секретарь молодёжного союза и заместитель директора по делам молодежи -> заместитель директора
# ['заместитель директора', 'заместитель директора']
# специалист по снабжению и сбыту -> специалист
# ['специалист']
# руководитель теплоэнергетической службы -> руководитель
# ['руководитель']
# менеджер по привлечению клиентов -> менеджер
# ['менеджер']
# председатель сельскохозяйственной артели -> председатель
# ['председатель']
# инженер заправка -> инженер
# ['инженер']
# полевой инженер -> инженер
# ['инженер']
# инженер по тракторный парк -> инженер
# ['инженер']
# бригадир по кормопроизводству -> бригадир
# ['бригадир']
# механик-водитель автотранспортной и сельхозтехники -> механик-водитель
# ['механик-водитель']
# инструктор по обучению -> инструктор
# ['инструктор']
# старший инженер по эксплуатации автомобильной техники -> старший инженер
# ['старший инженер', 'старший инженер']
# мастер газовая заправка -> мастер
# ['мастер']
# инженер неразрушающего контроля -> инженер
# ['инженер']
# главный инженер инспектор по чартакскому району -> главный инженер
# ['главный инженер', 'главный инженер']
# ведущий специалист по делам механизации -> ведущий специалист
# ['ведущий специалист', 'ведущий специалист']
# ведущий инженер участка механизации животноводческого комплекса -> ведущий инженер
# ['ведущий инженер', 'ведущий инженер']
# инженер теплотехник -> инженер
# ['инженер']
# слесарь по ремонту бульдозеров -> слесарь
# ['слесарь']
# инженер по наладке и испытаниям систем автоматического управления га -> инженер
# ['инженер']
# специалист направления ветеринарно-санитарной экспертизы -> специалист
# ['специалист']
# специалист по обслуживанию и монтажу бс -> специалист
# ['специалист']
# специалист по монтажу сигнализация -> специалист
# ['специалист']
# инструктор пдп -> инструктор
# ['инструктор']
# заведующий ремонтной механической мастерской -> заведующий ремонтной мастерской
# ['заведующий ремонтной мастерской']
# менеджер службы материально-технического обеспечения и общих вопросов -> менеджер
# ['менеджер']
# специалист по обслуживанию банкоматов -> специалист
# ['специалист']
# специалист по технической поддержке -> специалист
# ['специалист']
# ведущий инженер службы технологического транспорта -> ведущий инженер
# ['ведущий инженер', 'ведущий инженер']
# руководитель площадок по откорму бройлеров -> руководитель
# ['руководитель']
# генеральный директор бизнес-единицы -> генеральный директор
# ['генеральный директор', 'директор']
# инженер агрометеоролог -> инженер
# ['инженер']
# менеджер по клинингу -> менеджер
# ['менеджер']
# оператор-наладчик по розливу молочной продукции -> оператор-наладчик
# ['оператор-наладчик']
# специалист отдела сервисного обслуживания и предпродажной подготовки -> специалист
# ['специалист']
# специалист по снабжению / инженер по снабжению / экономист по снабжению -> инженер по снабжению
# ['инженер по снабжению', 'специалист', 'экономист', 'инженер']
# инженер по снабжению / экономист-снабженец -> инженер по снабжению
# ['инженер по снабжению', 'инженер']
# механик ломоперерабатывающего оборудования -> механик
# ['механик']
# дежурный механик транспортного отдела -> механик
# ['механик']
# бригадир / мастер участка по ремонту электронной аппаратуры и кип -> мастер участка
# ['мастер участка', 'бригадир', 'мастер']
# руководитель научно-консультационного центра группы компаний агрохим -> руководитель
# ['руководитель']
# механик по ремонту сельскохозяйственной техники и оборудования -> механик
# ['механик']
# главный агроном овощеводство -> главный агроном
# ['главный агроном', 'главный агроном']
# старший агроном по развитию технологий орошения -> старший агроном
# ['старший агроном', 'старший агроном']
# менеджер по консервантам и ветеринарным вопросам -> менеджер
# ['менеджер']
# техник игрового оборудования -> техник
# ['техник']
# водитель штабелера -> водитель
# ['водитель']
# специалист отдела контроля склада -> специалист
# ['специалист']
# менеджер по продажам ветеринарных препаратов -> менеджер по продажам
# ['менеджер по продажам', 'менеджер']
# инженер слаботочных систем -> инженер
# ['инженер']
# инженер сигнализация -> инженер
# ['инженер']
# электрик подстанционных сетей -> электрик
# ['электрик']
# администратор сельскохозяйственного кооперативного потребительского рынка -> администратор
# ['администратор']
# инженер службы безопасности -> инженер
# ['инженер']
# начальник участка водоснабжения -> начальник участка
# ['начальник участка']
# специалист видеонаблюдения -> специалист
# ['специалист']
# механик транспортного цеха -> механик
# ['механик']
# главный специалист государственного технического надзора -> главный специалист
# ['главный специалист', 'главный специалист']
# продавец-консультант сельскохозяйственных запчастей -> продавец-консультант
# ['продавец-консультант']
# преподаватель кафедры " растениеводство и кормопроизводство" -> преподаватель
# ['преподаватель']
# бригадир зерноводческой бригады сельскохозяйственного производства -> бригадир
# ['бригадир']
# главный специалист паразитологического отдела -> главный специалист
# ['главный специалист', 'главный специалист']

# %%
# Словарь для перевода названий месяцев на русском языке
months = {
    'Январь': 1, 'Февраль': 2, 'Март': 3, 'Апрель': 4, 'Май': 5, 'Июнь': 6,
    'Июль': 7, 'Август': 8, 'Сентябрь': 9, 'Октябрь': 10, 'Ноябрь': 11, 'Декабрь': 12,
    'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6,
    'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12
}

# Функция для преобразования строки в дату
def convert_to_date(date_str):
    if date_str is None or date_str == 'None' or date_str.lower() == 'currently':
        return None
    else:
        month_str, year_str = date_str.split()
        month = months.get(month_str, 1)  # Значение по умолчанию - январь
        year = int(year_str)
        return datetime(year, month, 1)

# Преобразование столбцов start и end в даты
jobs_df['start_ts'] = jobs_df['start'].apply(convert_to_date)
jobs_df['end_ts'] = jobs_df['end'].apply(convert_to_date)

# Функция для расчета продолжительности работы в месяцах
def calculate_duration(row):
    start_date = row['start_ts']
    end_date = row['end_ts'] if row['end_ts'] is not None else datetime.now()
    return (end_date.year - start_date.year) * 12 + end_date.month - start_date.month

# Расчет продолжительности работы для каждой записи
jobs_df['duration_months'] = jobs_df.apply(calculate_duration, axis=1)

# Оптимизация скрипта расчета стажа

# Сортировка df_jobs по person_id и дате начала работы
jobs_df = jobs_df.sort_values(by=['person_id', 'start_ts'])

# Инициализация словаря для хранения накопленного стажа для каждого person_id
accumulated_experience = {}

last_job_start_dict = {}

last_added_exp = {}

# Расчет стажа в одном проходе
def calculate_optimized_experience(row):
    person_id = row['person_id']
    start_date: datetime = row['start_ts']
    experience = accumulated_experience.get(person_id, 0)
    last_job_start = last_job_start_dict.get(person_id, None)
    if experience < 0:
        print("Expirience is negative...")
    assuming_approx_prev_job_start = start_date - relativedelta(months=experience)

    # Проверка на вторую одновременную работу
    if last_job_start is not None and assuming_approx_prev_job_start < last_job_start:
        # Расчет разницы между датами
        difference = relativedelta(start_date, last_job_start)
        # Преобразование разницы в общее количество месяцев
        total_months = difference.years * 12 + difference.months
        if total_months < 0:
            print("TM is negative...")
        exp_to_substract = last_added_exp.get(person_id, 0)
        experience += total_months - exp_to_substract
        

    # Обновление накопленного стажа для person_id
    accumulated_experience[person_id] = experience + row['duration_months']
    last_added_exp[person_id] = row['duration_months']
    last_job_start_dict[person_id] = start_date
    return experience

jobs_df['experience_at_start'] = jobs_df.apply(calculate_optimized_experience, axis=1)

# Вывод результатов
print(jobs_df[['start', 'end', 'duration_months', 'experience_at_start']])
# Out:
#               start            end  duration_months  experience_at_start
# 0       Август 2018           None               63                    0
# 1       Август 2018    Ноябрь 2019               15                    0
# 3         Июль 2013  Сентябрь 2013                2                    0
# 2       Август 2014   Октябрь 2014                2                    2
# 4     Сентябрь 2018           None               62                    0
# ...             ...            ...              ...                  ...
# 4329    Август 1981           None              507                   60
# 4334      Июнь 2019    Август 2019                2                    0
# 4333  Сентябрь 2019    Ноябрь 2019                2                    2
# 4332   Декабрь 2019    Август 2020                8                    5
# 4331    Август 2020           None               39                   13
#
# [4335 rows x 4 columns]

# %%
jobs_df['cluster'] = np.where(jobs_df['experience_at_start'] < 6, -2, 0)

for index, row in jobs_df.iterrows():
    if row['cluster'] == -2 and contains_all_words_from_top(row['job_name_norm'], top_percent_values):
        jobs_df.at[index, 'cluster'] = 0

# %%
# Удаление стоп-слов из нормализованного представления наименования профессии

# Скачивание списка стоп-слов
nltk.download('stopwords')
nltk.download('punkt')

stop_words = set(stopwords.words('russian'))

# Load additional stop words from the file stopwords-ru.json
ru_additional_stop_words_file = '../stop-words/stopwords-ru.json'
with open(ru_additional_stop_words_file, 'r', encoding='utf-8') as f:
    ru_additional_stop_words_file = set(json.load(f))

# Combine the NLTK stopwords and additional words to exclude
stop_words = stop_words.union(ru_additional_stop_words_file)

stop_words -= set(words_to_explicitly_check)

def remove_stop_words(text):
    # Разбиение текста на слова
    word_tokens = word_tokenize(text)

    # Фильтрация стоп-слов
    filtered_text = [word for word in word_tokens if not word in stop_words]

    # Сборка обратно в строку
    res = ' '.join(filtered_text)

    if res != text:
        print("Убраны стоп-слова: ", text, " -> ", res)
    
    return res

# Применение функции к каждой строке в столбце DataFrame
jobs_df['job_name_norm'] = jobs_df['job_name_norm'].apply(remove_stop_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Yurik\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Yurik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Убраны стоп-слова:  временно  главного механика  ->  временно главного механика
# Убраны стоп-слова:  специалист по охране труда и технике безопасности  ->  специалист охране труда технике безопасности
# Убраны стоп-слова:  специалист по работе с клиентами  ->  специалист работе клиентами
# Убраны стоп-слова:  управляющая фермой до мая  ->  управляющая фермой мая
# Убраны стоп-слова:  зоотехник по кормлению  ->  зоотехник кормлению
# Убраны стоп-слова:  инженер по эксплуатации тракторный парк  ->  инженер эксплуатации тракторный парк
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  машинист вам  ->  машинист
# Убраны стоп-слова:  оператор автоматических и полуавтоматических линий станков и установок  ->  оператор автоматических полуавтоматических линий станков установок
# Убраны стоп-слова:  механик по ремонту автомобилей  ->  механик ремонту автомобилей
# Убраны стоп-слова:  начальник отдела по мп  ->  начальник отдела мп
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  есть опыт работы в сельском хозяйстве ремонт сельхозтехники  ->  опыт работы сельском хозяйстве ремонт сельхозтехники
# Убраны стоп-слова:  слесарь по ремонту автомобилей  ->  слесарь ремонту автомобилей
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  заместитель генерального директора по производству  ->  заместитель генерального директора производству
# Убраны стоп-слова:  инженер по эксплуатации машино-тракторного парка  ->  инженер эксплуатации машино-тракторного парка
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  директор по производству  ->  директор производству
# Убраны стоп-слова:  специалист по работе с клиентами  ->  специалист работе клиентами
# Убраны стоп-слова:  специалист по логистике  ->  специалист логистике
# Убраны стоп-слова:  менеджер по закупкам  ->  менеджер закупкам
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  ведущий менеджер по продажам  ->  ведущий менеджер продажам
# Убраны стоп-слова:  региональный менеджер по продажам  ->  региональный менеджер продажам
# Убраны стоп-слова:  заместитель управляющего по качеству  ->  заместитель управляющего качеству
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  эксплуатация и обслуживание большого алма-атинского канала  ->  эксплуатация обслуживание большого алма-атинского канала
# Убраны стоп-слова:  менеджер по рекламе  ->  менеджер рекламе
# Убраны стоп-слова:  менеджер по развитию бизнеса  ->  менеджер развитию бизнеса
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  старший--садовник  ->  старший -- садовник
# Убраны стоп-слова:  ветеринарный врач по контролю качества продукции  ->  ветеринарный врач контролю качества продукции
# Убраны стоп-слова:  оператор с пу  ->  оператор пу
# Убраны стоп-слова:  инженер по снабжению  ->  инженер снабжению
# Убраны стоп-слова:  специалист по охране труда  ->  специалист охране труда
# Убраны стоп-слова:  начальник отдела по ремонту и эксплуатации  ->  начальник отдела ремонту эксплуатации
# Убраны стоп-слова:  ветеринарный врач по контролю качества продукции  ->  ветеринарный врач контролю качества продукции
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  инженер по оборудованию  ->  инженер оборудованию
# Убраны стоп-слова:  ответственный за опытные поля ясна  ->  ответственный опытные поля ясна
# Убраны стоп-слова:  помощник службы приема и размещения  ->  помощник службы приема размещения
# Убраны стоп-слова:  монтажник ра и приборов  ->  монтажник ра приборов
# Убраны стоп-слова:  монтажник ра и приборов  ->  монтажник ра приборов
# Убраны стоп-слова:  монтажник ра и приборов  ->  монтажник ра приборов
# Убраны стоп-слова:  заместитель директора по развитию  ->  заместитель директора развитию
# Убраны стоп-слова:  инженер по сервису  ->  инженер сервису
# Убраны стоп-слова:  оператор-наладчик станков с чпу  ->  оператор-наладчик станков чпу
# Убраны стоп-слова:  оператор-наладчик станков с чпу  ->  оператор-наладчик станков чпу
# Убраны стоп-слова:  оператор станков с чпу  ->  оператор станков чпу
# Убраны стоп-слова:  начальник по  ->  начальник
# Убраны стоп-слова:  слесарь по ремонту оборудования  ->  слесарь ремонту оборудования
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  зоотехник по кормам  ->  зоотехник кормам
# Убраны стоп-слова:  менеджер по рекламе  ->  менеджер рекламе
# Убраны стоп-слова:  директор по производству  ->  директор производству
# Убраны стоп-слова:  оператор автоматической линии розлива мол продуктов и соков  ->  оператор автоматической линии розлива мол продуктов соков
# Убраны стоп-слова:  заместитель главы представительства фирмы "агро-кеми"  ->  заместитель главы представительства фирмы `` агро-кеми ''
# Убраны стоп-слова:  технолог-менеджер по оптовым продажам  ->  технолог-менеджер оптовым продажам
# Убраны стоп-слова:  помощник фермера на молочной ферме  ->  помощник фермера молочной ферме
# Убраны стоп-слова:  ветеринарный врач-терапевт района и города  ->  ветеринарный врач-терапевт района города
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  менеджер по работе с клиентами  ->  менеджер работе клиентами
# Убраны стоп-слова:  автослесарь по ремонту автомобилей и спецоборудования  ->  автослесарь ремонту автомобилей спецоборудования
# Убраны стоп-слова:  автослесарь по ремонту автомобилей и спецоборудования  ->  автослесарь ремонту автомобилей спецоборудования
# Убраны стоп-слова:  директор по производству  ->  директор производству
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  заместителя начальника по пп  ->  заместителя начальника пп
# Убраны стоп-слова:  начальник участка откорма и доращивания  ->  начальник участка откорма доращивания
# Убраны стоп-слова:  помощник шефа в ресторане  ->  помощник шефа ресторане
# Убраны стоп-слова:  специалист по логистике  ->  специалист логистике
# Убраны стоп-слова:  с января  ->  января
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  менеджер по продажам услуг  ->  менеджер продажам услуг
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  специалист-эксперт отдела по предоставлению прав пользования водными объектами  ->  специалист-эксперт отдела предоставлению прав пользования водными объектами
# Убраны стоп-слова:  механик по транспорту  ->  механик транспорту
# Убраны стоп-слова:  инженер по сервису  ->  инженер сервису
# Убраны стоп-слова:  профконсультант в лингвистическом образовательном центре  ->  профконсультант лингвистическом образовательном центре
# Убраны стоп-слова:  начальника управления ветеринарной медицины в городе донецке  ->  начальника управления ветеринарной медицины городе донецке
# Убраны стоп-слова:  заместитель начальника управления ветеринарной медицины в городе донецке  ->  заместитель начальника управления ветеринарной медицины городе донецке
# Убраны стоп-слова:  главный специалист-государственный инспектор ветеринарной медицины отдела государственной ветеринарной инспекции управления ветеринарной медицины в донецкой обла  ->  главный специалист-государственный инспектор ветеринарной медицины отдела государственной ветеринарной инспекции управления ветеринарной медицины донецкой обла
# Убраны стоп-слова:  начальник отдела противоэпизоотических мероприятий и лечебно-профилактической работы  ->  начальник отдела противоэпизоотических мероприятий лечебно-профилактической работы
# Убраны стоп-слова:  заместитель директора по животноводству  ->  заместитель директора животноводству
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  слесарь по ремонту оборудования  ->  слесарь ремонту оборудования
# Убраны стоп-слова:  срочная служба в армии  ->  срочная служба армии
# Убраны стоп-слова:  заместитель регионального управляющего по региону  ->  заместитель регионального управляющего региону
# Убраны стоп-слова:  механик по ремонту автотранспорта  ->  механик ремонту автотранспорта
# Убраны стоп-слова:  ветеринарный врач на свинокомплексе  ->  ветеринарный врач свинокомплексе
# Убраны стоп-слова:  ветеринарный врач на свинокомплексе  ->  ветеринарный врач свинокомплексе
# Убраны стоп-слова:  специалист по логистике  ->  специалист логистике
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  инженер по эксплуатации тракторный парк  ->  инженер эксплуатации тракторный парк
# Убраны стоп-слова:  инженер по эксплуатации тракторный парк  ->  инженер эксплуатации тракторный парк
# Убраны стоп-слова:  экономист-куратор по сопровождению сельскохозяйственных предприятий  ->  экономист-куратор сопровождению сельскохозяйственных предприятий
# Убраны стоп-слова:  главный редактор медиаканал по совместительству с основной работой  ->  главный редактор медиаканал совместительству основной работой
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  начальник пол  ->  начальник
# Убраны стоп-слова:  главный зоотехник по кормам  ->  главный зоотехник кормам
# Убраны стоп-слова:  заместитель генерального директора по производству  ->  заместитель генерального директора производству
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  заместипельдиретора по животноводству  ->  заместипельдиретора животноводству
# Убраны стоп-слова:  менеджер по закупкам  ->  менеджер закупкам
# Убраны стоп-слова:  директор по производству  ->  директор производству
# Убраны стоп-слова:  ведущий специалист-консультант по растениеводству отдела производственно-хозяйственного консультирования  ->  ведущий специалист-консультант растениеводству отдела производственно-хозяйственного консультирования
# Убраны стоп-слова:  инженер по снабжению  ->  инженер снабжению
# Убраны стоп-слова:  инженер по снабжению  ->  инженер снабжению
# Убраны стоп-слова:  инженер по оборудованию  ->  инженер оборудованию
# Убраны стоп-слова:  о / у обмп инспектор обслуживания видеозал специальный радио и офисной техники  ->  / обмп инспектор обслуживания видеозал специальный радио офисной техники
# Убраны стоп-слова:  менеджер по продажам услуг  ->  менеджер продажам услуг
# Убраны стоп-слова:  сотрудник отдела по предотвращению внештатных ситуаций  ->  сотрудник отдела предотвращению внештатных ситуаций
# Убраны стоп-слова:  начальник бесовского районного отдела филиала югу "россельхозцентр" по курской области  ->  начальник бесовского районного отдела филиала югу `` россельхозцентр '' курской области
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  менеджер по работе с клиентами  ->  менеджер работе клиентами
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  электрослесарь по обслуживанию и ремонту оборудования  ->  электрослесарь обслуживанию ремонту оборудования
# Убраны стоп-слова:  инженер по качеству  ->  инженер качеству
# Убраны стоп-слова:  слесарь по ремонту оборудования  ->  слесарь ремонту оборудования
# Убраны стоп-слова:  старший менеджер по продажам  ->  старший менеджер продажам
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  механик по транспорту  ->  механик транспорту
# Убраны стоп-слова:  механик по выпуску автотранспорта  ->  механик выпуску автотранспорта
# Убраны стоп-слова:  механик по выпуску автотранспорта  ->  механик выпуску автотранспорта
# Убраны стоп-слова:  инженер по сельскохозяйственной машинам  ->  инженер сельскохозяйственной машинам
# Убраны стоп-слова:  инженер по охране труда и технике безопасности  ->  инженер охране труда технике безопасности
# Убраны стоп-слова:  "гостехнадзора" наманганской области  ->  `` гостехнадзора '' наманганской области
# Убраны стоп-слова:  начальник отдела садоводства и виноградарства  ->  начальник отдела садоводства виноградарства
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  механик по выпуску автотранспорта  ->  механик выпуску автотранспорта
# Убраны стоп-слова:  слесарь по ремонту автомобилей  ->  слесарь ремонту автомобилей
# Убраны стоп-слова:  сборщиком в грибной цех  ->  сборщиком грибной цех
# Убраны стоп-слова:  оператор станков с программным управлением  ->  оператор станков программным управлением
# Убраны стоп-слова:  машинист агрегата для создания набивочных рукавов  ->  машинист агрегата создания набивочных рукавов
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  директор по производству  ->  директор производству
# Убраны стоп-слова:  региональный менеджер по продажам  ->  региональный менеджер продажам
# Убраны стоп-слова:  ветеринарный консультант по работе с апк  ->  ветеринарный консультант работе апк
# Убраны стоп-слова:  зоотехник по кормам  ->  зоотехник кормам
# Убраны стоп-слова:  зоотехник по кормлению  ->  зоотехник кормлению
# Убраны стоп-слова:  механик по ремонту автотранспорта  ->  механик ремонту автотранспорта
# Убраны стоп-слова:  менеджер по закупкам  ->  менеджер закупкам
# Убраны стоп-слова:  заместитель директора по животноводству  ->  заместитель директора животноводству
# Убраны стоп-слова:  консультант по животноводству  ->  консультант животноводству
# Убраны стоп-слова:  специалист по благоустройству  ->  специалист благоустройству
# Убраны стоп-слова:  консультант по животноводству  ->  консультант животноводству
# Убраны стоп-слова:  консультант по животноводству  ->  консультант животноводству
# Убраны стоп-слова:  заместитель директора по животноводству  ->  заместитель директора животноводству
# Убраны стоп-слова:  заместитель директора по животноводству  ->  заместитель директора животноводству
# Убраны стоп-слова:  главный заместитель директора по животноводству  ->  главный заместитель директора животноводству
# Убраны стоп-слова:  аппаратчик по розливу и охлаждению молока  ->  аппаратчик розливу охлаждению молока
# Убраны стоп-слова:  заместитель председателя совета директоров по животноводству  ->  заместитель председателя совета директоров животноводству
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  агент по продаже недвижимости  ->  агент продаже недвижимости
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  представитель гв на предприятии  ->  представитель гв предприятии
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  региональный менеджер по продажам  ->  региональный менеджер продажам
# Убраны стоп-слова:  специалист по работе с клиентами  ->  специалист работе клиентами
# Убраны стоп-слова:  механик по транспорту  ->  механик транспорту
# Убраны стоп-слова:  механик по выпуску автотранспорта  ->  механик выпуску автотранспорта
# Убраны стоп-слова:  региональный менеджер по продажам  ->  региональный менеджер продажам
# Убраны стоп-слова:  работник по  ->  работник
# Убраны стоп-слова:  экспертный консультант по развитию производства  ->  экспертный консультант развитию производства
# Убраны стоп-слова:  региональный менеджер по продажам  ->  региональный менеджер продажам
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  начальник участка откорма и доращивания  ->  начальник участка откорма доращивания
# Убраны стоп-слова:  инженер по охране труда и технике безопасности  ->  инженер охране труда технике безопасности
# Убраны стоп-слова:  слесарь по ремонту оборудования  ->  слесарь ремонту оборудования
# Убраны стоп-слова:  инженер по качеству  ->  инженер качеству
# Убраны стоп-слова:  главный агроном по защите растений  ->  главный агроном защите растений
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  менеджер по работе с клиентами  ->  менеджер работе клиентами
# Убраны стоп-слова:  ландшафтное проектирование на договорной основе с кво «фсб россии»  ->  ландшафтное проектирование договорной основе кво « фсб россии »
# Убраны стоп-слова:  инженер-садово паркового и ландшафтного строительства  ->  инженер-садово паркового ландшафтного строительства
# Убраны стоп-слова:  менеджер по работе с клиентами  ->  менеджер работе клиентами
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  сборщик деталей и древесины  ->  сборщик деталей древесины
# Убраны стоп-слова:  проводник в отпускной цех  ->  проводник отпускной цех
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  начальник отдела апк и природопользования  ->  начальник отдела апк природопользования
# Убраны стоп-слова:  инженер по охране труда и технике безопасности  ->  инженер охране труда технике безопасности
# Убраны стоп-слова:  сборщик электрических машин и аппаратов  ->  сборщик электрических машин аппаратов
# Убраны стоп-слова:  слесарь-электрик по ремонту электрооборудования  ->  слесарь-электрик ремонту электрооборудования
# Убраны стоп-слова:  старший менеджер по закупкам  ->  старший менеджер закупкам
# Убраны стоп-слова:  менеджер по закупкам  ->  менеджер закупкам
# Убраны стоп-слова:  электромонтер по ремонту и обслуживанию электрооборудования  ->  электромонтер ремонту обслуживанию электрооборудования
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  менеджер по закупкам  ->  менеджер закупкам
# Убраны стоп-слова:  менеджер по развитию бизнеса  ->  менеджер развитию бизнеса
# Убраны стоп-слова:  механик по ремонту автомобилей  ->  механик ремонту автомобилей
# Убраны стоп-слова:  заместитель директора по животноводству  ->  заместитель директора животноводству
# Убраны стоп-слова:  инженер по эксплуатации машино-тракторного парка  ->  инженер эксплуатации машино-тракторного парка
# Убраны стоп-слова:  региональный менеджер по продажам  ->  региональный менеджер продажам
# Убраны стоп-слова:  слесарь по ремонту оборудования  ->  слесарь ремонту оборудования
# Убраны стоп-слова:  менеджер по работе с клиентами  ->  менеджер работе клиентами
# Убраны стоп-слова:  инженер по снабжению  ->  инженер снабжению
# Убраны стоп-слова:  с  ->
# Убраны стоп-слова:  заместитель генерального директора по производству  ->  заместитель генерального директора производству
# Убраны стоп-слова:  механик по выпуску автотранспорта  ->  механик выпуску автотранспорта
# Убраны стоп-слова:  инженер по снабжению  ->  инженер снабжению
# Убраны стоп-слова:  механик по ремонту автотранспорта  ->  механик ремонту автотранспорта
# Убраны стоп-слова:  начальника отдела противоэпизоотических мероприятий и незаразных болезней животных  ->  начальника отдела противоэпизоотических мероприятий незаразных болезней животных
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  зоотехник по кормам  ->  зоотехник кормам
# Убраны стоп-слова:  оператор станков с чпу  ->  оператор станков чпу
# Убраны стоп-слова:  заместитель начальника склада по техническим вопросам  ->  заместитель начальника склада техническим вопросам
# Убраны стоп-слова:  агроном по кормопроизводству  ->  агроном кормопроизводству
# Убраны стоп-слова:  инженер по сельскохозяйственной машинам  ->  инженер сельскохозяйственной машинам
# Убраны стоп-слова:  водитель-курьер категории с  ->  водитель-курьер категории
# Убраны стоп-слова:  и п  ->  п
# Убраны стоп-слова:  инженер по эксплуатации тракторный парк  ->  инженер эксплуатации тракторный парк
# Убраны стоп-слова:  менеджер по развитию бизнеса  ->  менеджер развитию бизнеса
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  начальник участка откорма и доращивания  ->  начальник участка откорма доращивания
# Убраны стоп-слова:  специалист по охране труда и технике безопасности  ->  специалист охране труда технике безопасности
# Убраны стоп-слова:  специалист по охране труда и технике безопасности  ->  специалист охране труда технике безопасности
# Убраны стоп-слова:  специалист по охране труда и технике безопасности  ->  специалист охране труда технике безопасности
# Убраны стоп-слова:  гос инспектор по карантину растений в крым  ->  гос инспектор карантину растений крым
# Убраны стоп-слова:  переработчик птицы и обвальщик птицы в балочном отделении убойно-перерабатывающего комплекса  ->  переработчик птицы обвальщик птицы балочном отделении убойно-перерабатывающего комплекса
# Убраны стоп-слова:  менеджер по работе с клиентами  ->  менеджер работе клиентами
# Убраны стоп-слова:  менеджер по работе с клиентами  ->  менеджер работе клиентами
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  аппаратчик подготовки сырья и отпуска полуфабрикатов  ->  аппаратчик подготовки сырья отпуска полуфабрикатов
# Убраны стоп-слова:  диспетчер по транспорту  ->  диспетчер транспорту
# Убраны стоп-слова:  слесарь по ремонту автомобилей  ->  слесарь ремонту автомобилей
# Убраны стоп-слова:  менеджер по уборке зерновых  ->  менеджер уборке зерновых
# Убраны стоп-слова:  мастер-отделения фаршесоставления и формовки  ->  мастер-отделения фаршесоставления формовки
# Убраны стоп-слова:  менеджер по уборке зерновых  ->  менеджер уборке зерновых
# Убраны стоп-слова:  инженер по эксплуатации тракторный парк  ->  инженер эксплуатации тракторный парк
# Убраны стоп-слова:  наладчик оборудования в производстве питания  ->  наладчик оборудования производстве питания
# Убраны стоп-слова:  второй секретарь  ->  секретарь
# Убраны стоп-слова:  ветеринарный врач-специалист по воспроизводству  ->  ветеринарный врач-специалист воспроизводству
# Убраны стоп-слова:  механик по транспорту  ->  механик транспорту
# Убраны стоп-слова:  от ассистента до доцента кафедры животноводства  ->  ассистента доцента кафедры животноводства
# Убраны стоп-слова:  от бригадира до начальника производства  ->  бригадира начальника производства
# Убраны стоп-слова:  от слесаря до главного инженера  ->  слесаря главного инженера
# Убраны стоп-слова:  инженер по инструменту  ->  инженер инструменту
# Убраны стоп-слова:  инженер по инструменту  ->  инженер инструменту
# Убраны стоп-слова:  электрослесарь дежурный и по ремонту оборудования  ->  электрослесарь дежурный ремонту оборудования
# Убраны стоп-слова:  электромонтер по ремонту и обслуживанию электрооборудования  ->  электромонтер ремонту обслуживанию электрооборудования
# Убраны стоп-слова:  электрослесарь дежурный и по ремонту оборудования  ->  электрослесарь дежурный ремонту оборудования
# Убраны стоп-слова:  специалист по логистике  ->  специалист логистике
# Убраны стоп-слова:  тестовой пшеничных и элитных сортов хлеба  ->  тестовой пшеничных элитных сортов хлеба
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  специалист по благоустройству  ->  специалист благоустройству
# Убраны стоп-слова:  специалист по благоустройству  ->  специалист благоустройству
# Убраны стоп-слова:  оператор по искусственному осеменению птицы  ->  оператор искусственному осеменению птицы
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  слесарь по ремонту оборудования  ->  слесарь ремонту оборудования
# Убраны стоп-слова:  заместитель главного специалиста по закупкам оборудования  ->  заместитель главного специалиста закупкам оборудования
# Убраны стоп-слова:  заместитель руководителя управления по закупкам оборудования  ->  заместитель руководителя управления закупкам оборудования
# Убраны стоп-слова:  заместитель директора по развитию  ->  заместитель директора развитию
# Убраны стоп-слова:  ветеринарный врач по контролю качества продукции  ->  ветеринарный врач контролю качества продукции
# Убраны стоп-слова:  специалист по охране труда  ->  специалист охране труда
# Убраны стоп-слова:  категория в с е  ->  категория
# Убраны стоп-слова:  агент по развитию рынка  ->  агент развитию рынка
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  заведующий ветеринарным участком из  ->  заведующий ветеринарным участком
# Убраны стоп-слова:  по совместительству  ->  совместительству
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  агроном по кормопроизводству  ->  агроном кормопроизводству
# Убраны стоп-слова:  региональный менеджер по продажам  ->  региональный менеджер продажам
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  аппаратчик сгущения молока и молочного сырья  ->  аппаратчик сгущения молока молочного сырья
# Убраны стоп-слова:  менеджер по закупке сельскохозяйственной продукции  ->  менеджер закупке сельскохозяйственной продукции
# Убраны стоп-слова:  менеджер по закупке сельскохозяйственной продукции  ->  менеджер закупке сельскохозяйственной продукции
# Убраны стоп-слова:  менеджер по закупкам  ->  менеджер закупкам
# Убраны стоп-слова:  менеджер по закупкам  ->  менеджер закупкам
# Убраны стоп-слова:  слесарь по ремонту автомобилей  ->  слесарь ремонту автомобилей
# Убраны стоп-слова:  слесарь по ремонту автомобилей  ->  слесарь ремонту автомобилей
# Убраны стоп-слова:  ведущий менеджер по продажам  ->  ведущий менеджер продажам
# Убраны стоп-слова:  от механизатора до  главы хозяйство  ->  механизатора главы хозяйство
# Убраны стоп-слова:  дежурный по залу железнодорожного вокзала  ->  дежурный залу железнодорожного вокзала
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  заведующий сектора отдела надзора в области обращения с животными  ->  заведующий сектора отдела надзора области обращения животными
# Убраны стоп-слова:  производство и реализация органо-бактериальных удобрений  ->  производство реализация органо-бактериальных удобрений
# Убраны стоп-слова:  агроном по защите растений  ->  агроном защите растений
# Убраны стоп-слова:  менеджер по продажам  ->  менеджер продажам
# Убраны стоп-слова:  мастер-механик по обслуживанию авто и электро погрузчиков импортного производства  ->  мастер-механик обслуживанию авто электро погрузчиков импортного производства
# Убраны стоп-слова:  аппаратчик по выращиванию монокристаллов сапфира  ->  аппаратчик выращиванию монокристаллов сапфира
# Убраны стоп-слова:  зоотехник по кормлению  ->  зоотехник кормлению
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  ветеринарный врач по контролю качества продукции  ->  ветеринарный врач контролю качества продукции
# Убраны стоп-слова:  менеджер по развитию бизнеса  ->  менеджер развитию бизнеса
# Убраны стоп-слова:  начальник отдела по работе с внешними торговыми сетями  ->  начальник отдела работе внешними торговыми сетями
# Убраны стоп-слова:  техник-проектировщик службы асу и тп  ->  техник-проектировщик службы асу тп
# Убраны стоп-слова:  менеджер по рекламе  ->  менеджер рекламе
# Убраны стоп-слова:  заместитель директора по производству  ->  заместитель директора производству
# Убраны стоп-слова:  помощник зоотехника по кормлению  ->  помощник зоотехника кормлению

# %%
is_lemmatization_turned_on = cfg['lemmatize_job_names']
if is_lemmatization_turned_on:
    def lemmatize_text(text):
        morph = pymorphy2.MorphAnalyzer()
        words = text.split()  # Разбиение текста на слова
        lemmatized_words = [morph.parse(word)[0].normal_form for word in words]
        return ' '.join(lemmatized_words)
    
    # Применение функции к столбцу DataFrame
    jobs_df['job_name_norm_lemmatized'] = jobs_df['job_name_norm'].apply(lemmatize_text)

# %%
# Установка значения -3 в столбце 'cluster' для строк, где длина 'job_name_norm' меньше 5
jobs_df.loc[jobs_df['job_name_norm'].str.len() < 5, 'cluster'] = -3

print("Убрано из рассмотрения строк по причине пустоты/недостаточной длинны имени профессии: ", (jobs_df['cluster'] == -3).sum())
# Out:
# Удалено строк по причине пустоты/недостаточной длинны имени профессии:  10

# %%
# Подключение к базе данных для сохранения сниппета
db_path_norm = "../db/normalized_data.db"
conn_norm = sqlite3.connect(db_path_norm)

jobs_df.to_sql(name='jobs', con=conn_norm, if_exists='replace', index=False)
# Out:
# 4335
